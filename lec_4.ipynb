# %% [markdown]
# <a href="https://colab.research.google.com/github/Jina0202/PyTorchZeroToAll/blob/main/lec_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #lecture 5 Linear Regression in the PyTorch way
#
# ##1) Design model using class with Variables
#
# ##2) Construct loss and optimizer (select from PyTorch API)
#
# ##3) Training cycle (forward, backward, update)

# %%
###step 1
import torch
from torch.autograd import Variable
#data definition (3x1 MATRIX)
#3data, each data has 1 value x --> 일반화 nx1 MATRIX
#changed the form into MATRIX
x_data=Variable(torch.Tensor([[1.0],[2.0],[3.0]]))
y_data=Variable(torch.Tensor([[2.0],[4.0],[6.0]]))

class Model(torch.nn.Module): 
  #아무렇게나 이름 지음->Model, Model은 torch.nn.Module의 subclass
  #two function: __init__(), forward()
  def __init__(self):
    """
    In the constructor wew instantiate tow nn.Linear module
    """
    super(Model,self).__init__() #going to call super in it, do some initializaion task or creat element,some component
    self.linear=torch.nn.Linear(1,1) #make one linear block: (input,output) input, output is 1 bc x, y value is one each
  
  def forward(self,x): #not going to use our own weight, but use the block we initialized in it
    y_pred=self.linear(x)
    return y_pred
model=Model()
###step 2
#Construct our loss funtion and an Optimizer. The call to model.parameters
#in the SGD constructor will contain the learnable parameters of the two
#nn.Linear modules whoch are members of the model.
criterion=torch.nn.MSELoss(reduction='mean') #라이브러리
optimizer=torch.optim.SGD(model.parameters(),lr=0.01) #알고리즘 compute data same times-앞 영상방식 zip들어간 방식보다 효율적 

###step 3
#Training loop
for epoch in range(500):
  #forward poss: compute predicted y by passing x to the model
  y_pred = model(x_data) #s_data: x_data=matrix

  #Compute and print loss
  loss=criterion(y_pred, y_data) #MSE계산
  print(epoch, loss.item()) 

  #Zero gradients, perform a backward pass, and update the weights
  optimizer.zero_grad() #initialize all the gradients
  loss.backward()
  optimizer.step() #update variable <</////////how??

  #After Training
  hour_var=Variable (torch.Tensor([[4.0]]))
  print("predict (after training)", 4, model.forward(hour_var).data[0][0])
# Out:
# 0 14.749600410461426
# predict (after training) 4 tensor(1.8925)
# 1 11.6611909866333
# predict (after training) 4 tensor(2.5464)
# 2 9.21996021270752
# predict (after training) 4 tensor(3.1278)
# 3 7.290285587310791
# predict (after training) 4 tensor(3.6448)
# 4 5.7649688720703125
# predict (after training) 4 tensor(4.1044)
# 5 4.559276580810547
# predict (after training) 4 tensor(4.5132)
# 6 3.606228828430176
# predict (after training) 4 tensor(4.8766)
# 7 2.8528854846954346
# predict (after training) 4 tensor(5.1998)
# 8 2.2573959827423096
# predict (after training) 4 tensor(5.4872)
# 9 1.7866815328598022
# predict (after training) 4 tensor(5.7428)
# 10 1.414596676826477
# predict (after training) 4 tensor(5.9701)
# 11 1.1204718351364136
# predict (after training) 4 tensor(6.1722)
# 12 0.8879709839820862
# predict (after training) 4 tensor(6.3519)
# 13 0.7041805386543274
# predict (after training) 4 tensor(6.5118)
# 14 0.5588931441307068
# predict (after training) 4 tensor(6.6540)
# 15 0.4440399706363678
# predict (after training) 4 tensor(6.7805)
# 16 0.35324403643608093
# predict (after training) 4 tensor(6.8930)
# 17 0.2814638614654541
# predict (after training) 4 tensor(6.9931)
# 18 0.22471444308757782
# predict (after training) 4 tensor(7.0821)
# 19 0.17984668910503387
# predict (after training) 4 tensor(7.1613)
# 20 0.14437010884284973
# predict (after training) 4 tensor(7.2318)
# 21 0.11631739884614944
# predict (after training) 4 tensor(7.2945)
# 22 0.09413262456655502
# predict (after training) 4 tensor(7.3503)
# 23 0.07658634334802628
# predict (after training) 4 tensor(7.4000)
# 24 0.06270632147789001
# predict (after training) 4 tensor(7.4442)
# 25 0.05172443017363548
# predict (after training) 4 tensor(7.4835)
# 26 0.043033573776483536
# predict (after training) 4 tensor(7.5186)
# 27 0.03615361079573631
# predict (after training) 4 tensor(7.5498)
# 28 0.03070519119501114
# predict (after training) 4 tensor(7.5776)
# 29 0.026388218626379967
# predict (after training) 4 tensor(7.6024)
# 30 0.022965751588344574
# predict (after training) 4 tensor(7.6245)
# 31 0.020250258967280388
# predict (after training) 4 tensor(7.6441)
# 32 0.018093815073370934
# predict (after training) 4 tensor(7.6617)
# 33 0.016379155218601227
# predict (after training) 4 tensor(7.6774)
# 34 0.01501388568431139
# predict (after training) 4 tensor(7.6913)
# 35 0.013924787752330303
# predict (after training) 4 tensor(7.7038)
# 36 0.013054035604000092
# predict (after training) 4 tensor(7.7150)
# 37 0.012355931103229523
# predict (after training) 4 tensor(7.7249)
# 38 0.011794338934123516
# predict (after training) 4 tensor(7.7338)
# 39 0.011340704746544361
# predict (after training) 4 tensor(7.7418)
# 40 0.010972417891025543
# predict (after training) 4 tensor(7.7489)
# 41 0.01067165657877922
# predict (after training) 4 tensor(7.7553)
# 42 0.010424303822219372
# predict (after training) 4 tensor(7.7611)
# 43 0.010219231247901917
# predict (after training) 4 tensor(7.7662)
# 44 0.01004764623939991
# predict (after training) 4 tensor(7.7709)
# 45 0.00990258064121008
# predict (after training) 4 tensor(7.7750)
# 46 0.009778488427400589
# predict (after training) 4 tensor(7.7788)
# 47 0.009671022184193134
# predict (after training) 4 tensor(7.7822)
# 48 0.009576724842190742
# predict (after training) 4 tensor(7.7853)
# 49 0.009492945857346058
# predict (after training) 4 tensor(7.7880)
# 50 0.009417497552931309
# predict (after training) 4 tensor(7.7906)
# 51 0.009348670952022076
# predict (after training) 4 tensor(7.7928)
# 52 0.009285119362175465
# predict (after training) 4 tensor(7.7949)
# 53 0.009225760586559772
# predict (after training) 4 tensor(7.7968)
# 54 0.009169753640890121
# predict (after training) 4 tensor(7.7986)
# 55 0.009116492234170437
# predict (after training) 4 tensor(7.8002)
# 56 0.009065459482371807
# predict (after training) 4 tensor(7.8017)
# 57 0.009016160853207111
# predict (after training) 4 tensor(7.8030)
# 58 0.00896831601858139
# predict (after training) 4 tensor(7.8043)
# 59 0.008921642787754536
# predict (after training) 4 tensor(7.8055)
# 60 0.008875944651663303
# predict (after training) 4 tensor(7.8065)
# 61 0.008831086568534374
# predict (after training) 4 tensor(7.8076)
# 62 0.0087868832051754
# predict (after training) 4 tensor(7.8085)
# 63 0.00874330010265112
# predict (after training) 4 tensor(7.8094)
# 64 0.008700186386704445
# predict (after training) 4 tensor(7.8103)
# 65 0.00865753460675478
# predict (after training) 4 tensor(7.8111)
# 66 0.008615243248641491
# predict (after training) 4 tensor(7.8118)
# 67 0.008573364466428757
# predict (after training) 4 tensor(7.8125)
# 68 0.008531740866601467
# predict (after training) 4 tensor(7.8132)
# 69 0.008490420877933502
# predict (after training) 4 tensor(7.8139)
# 70 0.008449376560747623
# predict (after training) 4 tensor(7.8145)
# 71 0.008408595807850361
# predict (after training) 4 tensor(7.8152)
# 72 0.008368058130145073
# predict (after training) 4 tensor(7.8157)
# 73 0.008327744901180267
# predict (after training) 4 tensor(7.8163)
# 74 0.008287650533020496
# predict (after training) 4 tensor(7.8169)
# 75 0.008247777819633484
# predict (after training) 4 tensor(7.8174)
# 76 0.008208086714148521
# predict (after training) 4 tensor(7.8180)
# 77 0.008168620988726616
# predict (after training) 4 tensor(7.8185)
# 78 0.008129348047077656
# predict (after training) 4 tensor(7.8190)
# 79 0.00809028372168541
# predict (after training) 4 tensor(7.8195)
# 80 0.008051401935517788
# predict (after training) 4 tensor(7.8200)
# 81 0.008012711070477962
# predict (after training) 4 tensor(7.8205)
# 82 0.007974212989211082
# predict (after training) 4 tensor(7.8210)
# 83 0.007935909554362297
# predict (after training) 4 tensor(7.8214)
# 84 0.007897808216512203
# predict (after training) 4 tensor(7.8219)
# 85 0.007859854027628899
# predict (after training) 4 tensor(7.8224)
# 86 0.007822105661034584
# predict (after training) 4 tensor(7.8228)
# 87 0.007784537971019745
# predict (after training) 4 tensor(7.8233)
# 88 0.007747149560600519
# predict (after training) 4 tensor(7.8237)
# 89 0.007709953468292952
# predict (after training) 4 tensor(7.8242)
# 90 0.007672907784581184
# predict (after training) 4 tensor(7.8246)
# 91 0.007636081427335739
# predict (after training) 4 tensor(7.8250)
# 92 0.007599413860589266
# predict (after training) 4 tensor(7.8255)
# 93 0.007562914397567511
# predict (after training) 4 tensor(7.8259)
# 94 0.00752658024430275
# predict (after training) 4 tensor(7.8263)
# 95 0.00749044818803668
# predict (after training) 4 tensor(7.8268)
# 96 0.007454463746398687
# predict (after training) 4 tensor(7.8272)
# 97 0.007418698165565729
# predict (after training) 4 tensor(7.8276)
# 98 0.007383042946457863
# predict (after training) 4 tensor(7.8280)
# 99 0.007347604725509882
# predict (after training) 4 tensor(7.8285)
# 100 0.0073123108595609665
# predict (after training) 4 tensor(7.8289)
# 101 0.007277183700352907
# predict (after training) 4 tensor(7.8293)
# 102 0.007242246996611357
# predict (after training) 4 tensor(7.8297)
# 103 0.007207475136965513
# predict (after training) 4 tensor(7.8301)
# 104 0.007172868121415377
# predict (after training) 4 tensor(7.8305)
# 105 0.00713840126991272
# predict (after training) 4 tensor(7.8309)
# 106 0.007104150950908661
# predict (after training) 4 tensor(7.8313)
# 107 0.007070013787597418
# predict (after training) 4 tensor(7.8318)
# 108 0.0070360940881073475
# predict (after training) 4 tensor(7.8322)
# 109 0.007002287078648806
# predict (after training) 4 tensor(7.8326)
# 110 0.006968650966882706
# predict (after training) 4 tensor(7.8330)
# 111 0.006935190409421921
# predict (after training) 4 tensor(7.8334)
# 112 0.00690189516171813
# predict (after training) 4 tensor(7.8338)
# 113 0.006868768483400345
# predict (after training) 4 tensor(7.8342)
# 114 0.006835779175162315
# predict (after training) 4 tensor(7.8346)
# 115 0.006802927702665329
# predict (after training) 4 tensor(7.8350)
# 116 0.006770280655473471
# predict (after training) 4 tensor(7.8354)
# 117 0.006737757474184036
# predict (after training) 4 tensor(7.8358)
# 118 0.006705412175506353
# predict (after training) 4 tensor(7.8362)
# 119 0.0066732000559568405
# predict (after training) 4 tensor(7.8366)
# 120 0.006641171872615814
# predict (after training) 4 tensor(7.8370)
# 121 0.0066092777997255325
# predict (after training) 4 tensor(7.8373)
# 122 0.006577529013156891
# predict (after training) 4 tensor(7.8377)
# 123 0.006545953452587128
# predict (after training) 4 tensor(7.8381)
# 124 0.006514514330774546
# predict (after training) 4 tensor(7.8385)
# 125 0.0064832293428480625
# predict (after training) 4 tensor(7.8389)
# 126 0.006452097091823816
# predict (after training) 4 tensor(7.8393)
# 127 0.0064211077988147736
# predict (after training) 4 tensor(7.8397)
# 128 0.006390267983078957
# predict (after training) 4 tensor(7.8401)
# 129 0.006359569728374481
# predict (after training) 4 tensor(7.8404)
# 130 0.006329056341201067
# predict (after training) 4 tensor(7.8408)
# 131 0.006298678461462259
# predict (after training) 4 tensor(7.8412)
# 132 0.006268391851335764
# predict (after training) 4 tensor(7.8416)
# 133 0.006238304078578949
# predict (after training) 4 tensor(7.8420)
# 134 0.006208343431353569
# predict (after training) 4 tensor(7.8424)
# 135 0.006178554613143206
# predict (after training) 4 tensor(7.8427)
# 136 0.006148872431367636
# predict (after training) 4 tensor(7.8431)
# 137 0.006119345780462027
# predict (after training) 4 tensor(7.8435)
# 138 0.006089939270168543
# predict (after training) 4 tensor(7.8439)
# 139 0.006060713902115822
# predict (after training) 4 tensor(7.8442)
# 140 0.006031608209013939
# predict (after training) 4 tensor(7.8446)
# 141 0.00600265571847558
# predict (after training) 4 tensor(7.8450)
# 142 0.005973806604743004
# predict (after training) 4 tensor(7.8454)
# 143 0.005945143755525351
# predict (after training) 4 tensor(7.8457)
# 144 0.005916573107242584
# predict (after training) 4 tensor(7.8461)
# 145 0.005888165906071663
# predict (after training) 4 tensor(7.8465)
# 146 0.005859881639480591
# predict (after training) 4 tensor(7.8468)
# 147 0.005831747781485319
# predict (after training) 4 tensor(7.8472)
# 148 0.0058037578128278255
# predict (after training) 4 tensor(7.8476)
# 149 0.005775888916105032
# predict (after training) 4 tensor(7.8479)
# 150 0.005748140159994364
# predict (after training) 4 tensor(7.8483)
# 151 0.0057205394841730595
# predict (after training) 4 tensor(7.8487)
# 152 0.005693081766366959
# predict (after training) 4 tensor(7.8490)
# 153 0.005665723234415054
# predict (after training) 4 tensor(7.8494)
# 154 0.005638530477881432
# predict (after training) 4 tensor(7.8498)
# 155 0.005611459258943796
# predict (after training) 4 tensor(7.8501)
# 156 0.005584503058344126
# predict (after training) 4 tensor(7.8505)
# 157 0.005557676311582327
# predict (after training) 4 tensor(7.8508)
# 158 0.005530997645109892
# predict (after training) 4 tensor(7.8512)
# 159 0.005504444241523743
# predict (after training) 4 tensor(7.8516)
# 160 0.00547799514606595
# predict (after training) 4 tensor(7.8519)
# 161 0.0054516964592039585
# predict (after training) 4 tensor(7.8523)
# 162 0.0054255202412605286
# predict (after training) 4 tensor(7.8526)
# 163 0.005399458575993776
# predict (after training) 4 tensor(7.8530)
# 164 0.005373541731387377
# predict (after training) 4 tensor(7.8533)
# 165 0.005347730591893196
# predict (after training) 4 tensor(7.8537)
# 166 0.005322060082107782
# predict (after training) 4 tensor(7.8540)
# 167 0.005296493414789438
# predict (after training) 4 tensor(7.8544)
# 168 0.005271051544696093
# predict (after training) 4 tensor(7.8547)
# 169 0.005245750769972801
# predict (after training) 4 tensor(7.8551)
# 170 0.005220561753958464
# predict (after training) 4 tensor(7.8554)
# 171 0.005195484962314367
# predict (after training) 4 tensor(7.8558)
# 172 0.005170547403395176
# predict (after training) 4 tensor(7.8561)
# 173 0.005145720671862364
# predict (after training) 4 tensor(7.8565)
# 174 0.005121006164699793
# predict (after training) 4 tensor(7.8568)
# 175 0.005096402019262314
# predict (after training) 4 tensor(7.8572)
# 176 0.005071933381259441
# predict (after training) 4 tensor(7.8575)
# 177 0.005047576501965523
# predict (after training) 4 tensor(7.8579)
# 178 0.005023353733122349
# predict (after training) 4 tensor(7.8582)
# 179 0.004999215714633465
# predict (after training) 4 tensor(7.8585)
# 180 0.004975211340934038
# predict (after training) 4 tensor(7.8589)
# 181 0.004951316863298416
# predict (after training) 4 tensor(7.8592)
# 182 0.004927555564790964
# predict (after training) 4 tensor(7.8596)
# 183 0.004903876688331366
# predict (after training) 4 tensor(7.8599)
# 184 0.0048803300596773624
# predict (after training) 4 tensor(7.8602)
# 185 0.004856892395764589
# predict (after training) 4 tensor(7.8606)
# 186 0.004833585117012262
# predict (after training) 4 tensor(7.8609)
# 187 0.0048103597946465015
# predict (after training) 4 tensor(7.8612)
# 188 0.004787252750247717
# predict (after training) 4 tensor(7.8616)
# 189 0.004764279816299677
# predict (after training) 4 tensor(7.8619)
# 190 0.004741401877254248
# predict (after training) 4 tensor(7.8622)
# 191 0.004718627315014601
# predict (after training) 4 tensor(7.8626)
# 192 0.0046959794126451015
# predict (after training) 4 tensor(7.8629)
# 193 0.004673438146710396
# predict (after training) 4 tensor(7.8632)
# 194 0.0046509793028235435
# predict (after training) 4 tensor(7.8636)
# 195 0.004628647118806839
# predict (after training) 4 tensor(7.8639)
# 196 0.0046064164489507675
# predict (after training) 4 tensor(7.8642)
# 197 0.004584296140819788
# predict (after training) 4 tensor(7.8645)
# 198 0.0045622955076396465
# predict (after training) 4 tensor(7.8649)
# 199 0.0045403786934912205
# predict (after training) 4 tensor(7.8652)
# 200 0.004518582485616207
# predict (after training) 4 tensor(7.8655)
# 201 0.00449686823412776
# predict (after training) 4 tensor(7.8658)
# 202 0.004475280176848173
# predict (after training) 4 tensor(7.8662)
# 203 0.004453790839761496
# predict (after training) 4 tensor(7.8665)
# 204 0.0044324048794806
# predict (after training) 4 tensor(7.8668)
# 205 0.0044111218303442
# predict (after training) 4 tensor(7.8671)
# 206 0.004389934241771698
# predict (after training) 4 tensor(7.8674)
# 207 0.00436885142698884
# predict (after training) 4 tensor(7.8678)
# 208 0.004347882699221373
# predict (after training) 4 tensor(7.8681)
# 209 0.0043269875459373
# predict (after training) 4 tensor(7.8684)
# 210 0.004306220915168524
# predict (after training) 4 tensor(7.8687)
# 211 0.0042855204083025455
# predict (after training) 4 tensor(7.8690)
# 212 0.0042649684473872185
# predict (after training) 4 tensor(7.8693)
# 213 0.004244483076035976
# predict (after training) 4 tensor(7.8697)
# 214 0.004224090371280909
# predict (after training) 4 tensor(7.8700)
# 215 0.004203799646347761
# predict (after training) 4 tensor(7.8703)
# 216 0.004183626733720303
# predict (after training) 4 tensor(7.8706)
# 217 0.0041635287925601006
# predict (after training) 4 tensor(7.8709)
# 218 0.00414353096857667
# predict (after training) 4 tensor(7.8712)
# 219 0.00412364536896348
# predict (after training) 4 tensor(7.8715)
# 220 0.0041038538329303265
# predict (after training) 4 tensor(7.8718)
# 221 0.004084113519638777
# predict (after training) 4 tensor(7.8721)
# 222 0.004064531996846199
# predict (after training) 4 tensor(7.8724)
# 223 0.004045006353408098
# predict (after training) 4 tensor(7.8728)
# 224 0.004025567788630724
# predict (after training) 4 tensor(7.8731)
# 225 0.004006251227110624
# predict (after training) 4 tensor(7.8734)
# 226 0.0039869993925094604
# predict (after training) 4 tensor(7.8737)
# 227 0.0039678579196333885
# predict (after training) 4 tensor(7.8740)
# 228 0.003948806319385767
# predict (after training) 4 tensor(7.8743)
# 229 0.003929836675524712
# predict (after training) 4 tensor(7.8746)
# 230 0.003910969477146864
# predict (after training) 4 tensor(7.8749)
# 231 0.003892181208357215
# predict (after training) 4 tensor(7.8752)
# 232 0.0038735170383006334
# predict (after training) 4 tensor(7.8755)
# 233 0.00385489990003407
# predict (after training) 4 tensor(7.8758)
# 234 0.0038363905623555183
# predict (after training) 4 tensor(7.8761)
# 235 0.003817969001829624
# predict (after training) 4 tensor(7.8764)
# 236 0.003799622878432274
# predict (after training) 4 tensor(7.8767)
# 237 0.003781380830332637
# predict (after training) 4 tensor(7.8770)
# 238 0.003763217478990555
# predict (after training) 4 tensor(7.8773)
# 239 0.003745157504454255
# predict (after training) 4 tensor(7.8776)
# 240 0.003727155504748225
# predict (after training) 4 tensor(7.8779)
# 241 0.003709272248670459
# predict (after training) 4 tensor(7.8781)
# 242 0.0036914607044309378
# predict (after training) 4 tensor(7.8784)
# 243 0.0036737266927957535
# predict (after training) 4 tensor(7.8787)
# 244 0.0036560799926519394
# predict (after training) 4 tensor(7.8790)
# 245 0.0036385406274348497
# predict (after training) 4 tensor(7.8793)
# 246 0.0036210513208061457
# predict (after training) 4 tensor(7.8796)
# 247 0.003603684948757291
# predict (after training) 4 tensor(7.8799)
# 248 0.0035863725934177637
# predict (after training) 4 tensor(7.8802)
# 249 0.003569145454093814
# predict (after training) 4 tensor(7.8805)
# 250 0.003552004462108016
# predict (after training) 4 tensor(7.8808)
# 251 0.0035349519457668066
# predict (after training) 4 tensor(7.8810)
# 252 0.0035179865080863237
# predict (after training) 4 tensor(7.8813)
# 253 0.003501074155792594
# predict (after training) 4 tensor(7.8816)
# 254 0.0034842751920223236
# predict (after training) 4 tensor(7.8819)
# 255 0.0034675353672355413
# predict (after training) 4 tensor(7.8822)
# 256 0.0034508786629885435
# predict (after training) 4 tensor(7.8825)
# 257 0.0034343188162893057
# predict (after training) 4 tensor(7.8828)
# 258 0.003417814848944545
# predict (after training) 4 tensor(7.8830)
# 259 0.0034014054108411074
# predict (after training) 4 tensor(7.8833)
# 260 0.0033850865438580513
# predict (after training) 4 tensor(7.8836)
# 261 0.0033688314724713564
# predict (after training) 4 tensor(7.8839)
# 262 0.0033526455517858267
# predict (after training) 4 tensor(7.8842)
# 263 0.0033365387935191393
# predict (after training) 4 tensor(7.8844)
# 264 0.0033205195795744658
# predict (after training) 4 tensor(7.8847)
# 265 0.00330458115786314
# predict (after training) 4 tensor(7.8850)
# 266 0.0032886946573853493
# predict (after training) 4 tensor(7.8853)
# 267 0.0032729171216487885
# predict (after training) 4 tensor(7.8855)
# 268 0.003257189178839326
# predict (after training) 4 tensor(7.8858)
# 269 0.003241562517359853
# predict (after training) 4 tensor(7.8861)
# 270 0.0032259980216622353
# predict (after training) 4 tensor(7.8864)
# 271 0.003210514783859253
# predict (after training) 4 tensor(7.8866)
# 272 0.0031950855627655983
# predict (after training) 4 tensor(7.8869)
# 273 0.0031797296833246946
# predict (after training) 4 tensor(7.8872)
# 274 0.003164471359923482
# predict (after training) 4 tensor(7.8875)
# 275 0.0031492796260863543
# predict (after training) 4 tensor(7.8877)
# 276 0.003134162398055196
# predict (after training) 4 tensor(7.8880)
# 277 0.003119109198451042
# predict (after training) 4 tensor(7.8883)
# 278 0.0031041244510561228
# predict (after training) 4 tensor(7.8885)
# 279 0.003089216537773609
# predict (after training) 4 tensor(7.8888)
# 280 0.0030743840616196394
# predict (after training) 4 tensor(7.8891)
# 281 0.003059620037674904
# predict (after training) 4 tensor(7.8893)
# 282 0.0030449272599071264
# predict (after training) 4 tensor(7.8896)
# 283 0.0030302954837679863
# predict (after training) 4 tensor(7.8899)
# 284 0.003015745198354125
# predict (after training) 4 tensor(7.8901)
# 285 0.003001270117238164
# predict (after training) 4 tensor(7.8904)
# 286 0.002986873732879758
# predict (after training) 4 tensor(7.8907)
# 287 0.0029725199565291405
# predict (after training) 4 tensor(7.8909)
# 288 0.0029582458082586527
# predict (after training) 4 tensor(7.8912)
# 289 0.0029440317302942276
# predict (after training) 4 tensor(7.8914)
# 290 0.0029298916924744844
# predict (after training) 4 tensor(7.8917)
# 291 0.0029158315155655146
# predict (after training) 4 tensor(7.8920)
# 292 0.002901824889704585
# predict (after training) 4 tensor(7.8922)
# 293 0.0028878822922706604
# predict (after training) 4 tensor(7.8925)
# 294 0.0028740328270941973
# predict (after training) 4 tensor(7.8927)
# 295 0.0028602220118045807
# predict (after training) 4 tensor(7.8930)
# 296 0.002846489427611232
# predict (after training) 4 tensor(7.8933)
# 297 0.002832811325788498
# predict (after training) 4 tensor(7.8935)
# 298 0.0028192249592393637
# predict (after training) 4 tensor(7.8938)
# 299 0.0028056816663593054
# predict (after training) 4 tensor(7.8940)
# 300 0.002792208455502987
# predict (after training) 4 tensor(7.8943)
# 301 0.0027787992730736732
# predict (after training) 4 tensor(7.8945)
# 302 0.002765447134152055
# predict (after training) 4 tensor(7.8948)
# 303 0.0027521662414073944
# predict (after training) 4 tensor(7.8950)
# 304 0.0027389556635171175
# predict (after training) 4 tensor(7.8953)
# 305 0.0027257928159087896
# predict (after training) 4 tensor(7.8955)
# 306 0.0027127088978886604
# predict (after training) 4 tensor(7.8958)
# 307 0.0026996878441423178
# predict (after training) 4 tensor(7.8960)
# 308 0.002686708467081189
# predict (after training) 4 tensor(7.8963)
# 309 0.0026737982407212257
# predict (after training) 4 tensor(7.8965)
# 310 0.0026609713677316904
# predict (after training) 4 tensor(7.8968)
# 311 0.0026481859385967255
# predict (after training) 4 tensor(7.8970)
# 312 0.002635474316775799
# predict (after training) 4 tensor(7.8973)
# 313 0.0026228271890431643
# predict (after training) 4 tensor(7.8975)
# 314 0.002610226394608617
# predict (after training) 4 tensor(7.8978)
# 315 0.002597684971988201
# predict (after training) 4 tensor(7.8980)
# 316 0.0025852180551737547
# predict (after training) 4 tensor(7.8983)
# 317 0.0025727981701493263
# predict (after training) 4 tensor(7.8985)
# 318 0.002560446970164776
# predict (after training) 4 tensor(7.8988)
# 319 0.0025481614284217358
# predict (after training) 4 tensor(7.8990)
# 320 0.0025359170977026224
# predict (after training) 4 tensor(7.8992)
# 321 0.0025237395893782377
# predict (after training) 4 tensor(7.8995)
# 322 0.002511619823053479
# predict (after training) 4 tensor(7.8997)
# 323 0.0024995659478008747
# predict (after training) 4 tensor(7.9000)
# 324 0.002487553283572197
# predict (after training) 4 tensor(7.9002)
# 325 0.002475617453455925
# predict (after training) 4 tensor(7.9005)
# 326 0.002463723998516798
# predict (after training) 4 tensor(7.9007)
# 327 0.0024518840946257114
# predict (after training) 4 tensor(7.9009)
# 328 0.0024401124101132154
# predict (after training) 4 tensor(7.9012)
# 329 0.0024284038227051497
# predict (after training) 4 tensor(7.9014)
# 330 0.002416734816506505
# predict (after training) 4 tensor(7.9016)
# 331 0.0024051303043961525
# predict (after training) 4 tensor(7.9019)
# 332 0.002393581671640277
# predict (after training) 4 tensor(7.9021)
# 333 0.0023820854257792234
# predict (after training) 4 tensor(7.9024)
# 334 0.002370634814724326
# predict (after training) 4 tensor(7.9026)
# 335 0.0023592521902173758
# predict (after training) 4 tensor(7.9028)
# 336 0.0023479380179196596
# predict (after training) 4 tensor(7.9031)
# 337 0.0023366559762507677
# predict (after training) 4 tensor(7.9033)
# 338 0.0023254428524523973
# predict (after training) 4 tensor(7.9035)
# 339 0.002314279554411769
# predict (after training) 4 tensor(7.9038)
# 340 0.0023031544405966997
# predict (after training) 4 tensor(7.9040)
# 341 0.0022920898627489805
# predict (after training) 4 tensor(7.9042)
# 342 0.002281088614836335
# predict (after training) 4 tensor(7.9044)
# 343 0.002270128345116973
# predict (after training) 4 tensor(7.9047)
# 344 0.002259230939671397
# predict (after training) 4 tensor(7.9049)
# 345 0.002248393604531884
# predict (after training) 4 tensor(7.9051)
# 346 0.0022375772241503
# predict (after training) 4 tensor(7.9054)
# 347 0.0022268425673246384
# predict (after training) 4 tensor(7.9056)
# 348 0.002216140041127801
# predict (after training) 4 tensor(7.9058)
# 349 0.002205501077696681
# predict (after training) 4 tensor(7.9060)
# 350 0.0021949128713458776
# predict (after training) 4 tensor(7.9063)
# 351 0.0021843828726559877
# predict (after training) 4 tensor(7.9065)
# 352 0.002173877088353038
# predict (after training) 4 tensor(7.9067)
# 353 0.0021634476725012064
# predict (after training) 4 tensor(7.9069)
# 354 0.002153049921616912
# predict (after training) 4 tensor(7.9072)
# 355 0.0021427159663289785
# predict (after training) 4 tensor(7.9074)
# 356 0.002132428577169776
# predict (after training) 4 tensor(7.9076)
# 357 0.0021221875213086605
# predict (after training) 4 tensor(7.9078)
# 358 0.0021120067685842514
# predict (after training) 4 tensor(7.9081)
# 359 0.00210184114985168
# predict (after training) 4 tensor(7.9083)
# 360 0.002091764472424984
# predict (after training) 4 tensor(7.9085)
# 361 0.0020817152690142393
# predict (after training) 4 tensor(7.9087)
# 362 0.002071723574772477
# predict (after training) 4 tensor(7.9089)
# 363 0.0020617591217160225
# predict (after training) 4 tensor(7.9092)
# 364 0.002051871968433261
# predict (after training) 4 tensor(7.9094)
# 365 0.0020420190412551165
# predict (after training) 4 tensor(7.9096)
# 366 0.0020322035998106003
# predict (after training) 4 tensor(7.9098)
# 367 0.0020224449690431356
# predict (after training) 4 tensor(7.9100)
# 368 0.002012742916122079
# predict (after training) 4 tensor(7.9102)
# 369 0.0020030748564749956
# predict (after training) 4 tensor(7.9105)
# 370 0.0019934524316340685
# predict (after training) 4 tensor(7.9107)
# 371 0.0019838891457766294
# predict (after training) 4 tensor(7.9109)
# 372 0.001974359154701233
# predict (after training) 4 tensor(7.9111)
# 373 0.0019648626912385225
# predict (after training) 4 tensor(7.9113)
# 374 0.0019554337486624718
# predict (after training) 4 tensor(7.9115)
# 375 0.001946047879755497
# predict (after training) 4 tensor(7.9117)
# 376 0.001936695072799921
# predict (after training) 4 tensor(7.9120)
# 377 0.0019274018704891205
# predict (after training) 4 tensor(7.9122)
# 378 0.0019181411480531096
# predict (after training) 4 tensor(7.9124)
# 379 0.00190893339458853
# predict (after training) 4 tensor(7.9126)
# 380 0.0018997712759301066
# predict (after training) 4 tensor(7.9128)
# 381 0.0018906515324488282
# predict (after training) 4 tensor(7.9130)
# 382 0.0018815742805600166
# predict (after training) 4 tensor(7.9132)
# 383 0.001872533350251615
# predict (after training) 4 tensor(7.9134)
# 384 0.001863531768321991
# predict (after training) 4 tensor(7.9136)
# 385 0.0018545979401096702
# predict (after training) 4 tensor(7.9138)
# 386 0.0018456884426996112
# predict (after training) 4 tensor(7.9140)
# 387 0.0018368292367085814
# predict (after training) 4 tensor(7.9143)
# 388 0.0018279998330399394
# predict (after training) 4 tensor(7.9145)
# 389 0.001819227822124958
# predict (after training) 4 tensor(7.9147)
# 390 0.001810497953556478
# predict (after training) 4 tensor(7.9149)
# 391 0.0018017878755927086
# predict (after training) 4 tensor(7.9151)
# 392 0.0017931299516931176
# predict (after training) 4 tensor(7.9153)
# 393 0.0017845240654423833
# predict (after training) 4 tensor(7.9155)
# 394 0.0017759603215381503
# predict (after training) 4 tensor(7.9157)
# 395 0.0017674298724159598
# predict (after training) 4 tensor(7.9159)
# 396 0.0017589520430192351
# predict (after training) 4 tensor(7.9161)
# 397 0.0017505032010376453
# predict (after training) 4 tensor(7.9163)
# 398 0.001742095686495304
# predict (after training) 4 tensor(7.9165)
# 399 0.0017337278695777059
# predict (after training) 4 tensor(7.9167)
# 400 0.0017254124395549297
# predict (after training) 4 tensor(7.9169)
# 401 0.0017171185463666916
# predict (after training) 4 tensor(7.9171)
# 402 0.0017088623717427254
# predict (after training) 4 tensor(7.9173)
# 403 0.0017006592825055122
# predict (after training) 4 tensor(7.9175)
# 404 0.0016924970550462604
# predict (after training) 4 tensor(7.9177)
# 405 0.0016843774355947971
# predict (after training) 4 tensor(7.9179)
# 406 0.0016762831946834922
# predict (after training) 4 tensor(7.9181)
# 407 0.0016682423884049058
# predict (after training) 4 tensor(7.9183)
# 408 0.0016602264950051904
# predict (after training) 4 tensor(7.9185)
# 409 0.0016522547230124474
# predict (after training) 4 tensor(7.9187)
# 410 0.00164432090241462
# predict (after training) 4 tensor(7.9189)
# 411 0.001636415719985962
# predict (after training) 4 tensor(7.9191)
# 412 0.001628559548407793
# predict (after training) 4 tensor(7.9193)
# 413 0.0016207356238737702
# predict (after training) 4 tensor(7.9195)
# 414 0.0016129562864080071
# predict (after training) 4 tensor(7.9196)
# 415 0.0016052090795710683
# predict (after training) 4 tensor(7.9198)
# 416 0.0015975100686773658
# predict (after training) 4 tensor(7.9200)
# 417 0.001589838764630258
# predict (after training) 4 tensor(7.9202)
# 418 0.0015821954002603889
# predict (after training) 4 tensor(7.9204)
# 419 0.0015746024437248707
# predict (after training) 4 tensor(7.9206)
# 420 0.0015670344000682235
# predict (after training) 4 tensor(7.9208)
# 421 0.0015595083823427558
# predict (after training) 4 tensor(7.9210)
# 422 0.001552028232254088
# predict (after training) 4 tensor(7.9212)
# 423 0.001544566242955625
# predict (after training) 4 tensor(7.9214)
# 424 0.0015371510526165366
# predict (after training) 4 tensor(7.9216)
# 425 0.0015297733480110765
# predict (after training) 4 tensor(7.9217)
# 426 0.00152242137119174
# predict (after training) 4 tensor(7.9219)
# 427 0.0015151196857914329
# predict (after training) 4 tensor(7.9221)
# 428 0.0015078355791047215
# predict (after training) 4 tensor(7.9223)
# 429 0.0015005938475951552
# predict (after training) 4 tensor(7.9225)
# 430 0.0014933926286175847
# predict (after training) 4 tensor(7.9227)
# 431 0.0014862166717648506
# predict (after training) 4 tensor(7.9229)
# 432 0.001479090191423893
# predict (after training) 4 tensor(7.9231)
# 433 0.0014719770988449454
# predict (after training) 4 tensor(7.9232)
# 434 0.0014649132499471307
# predict (after training) 4 tensor(7.9234)
# 435 0.0014578752452507615
# predict (after training) 4 tensor(7.9236)
# 436 0.001450872397981584
# predict (after training) 4 tensor(7.9238)
# 437 0.0014439154183492064
# predict (after training) 4 tensor(7.9240)
# 438 0.0014369828859344125
# predict (after training) 4 tensor(7.9242)
# 439 0.0014300771290436387
# predict (after training) 4 tensor(7.9243)
# 440 0.0014232186367735267
# predict (after training) 4 tensor(7.9245)
# 441 0.0014163661981001496
# predict (after training) 4 tensor(7.9247)
# 442 0.0014095745282247663
# predict (after training) 4 tensor(7.9249)
# 443 0.0014028018340468407
# predict (after training) 4 tensor(7.9251)
# 444 0.0013960730284452438
# predict (after training) 4 tensor(7.9252)
# 445 0.001389360404573381
# predict (after training) 4 tensor(7.9254)
# 446 0.0013827037764713168
# predict (after training) 4 tensor(7.9256)
# 447 0.0013760494766756892
# predict (after training) 4 tensor(7.9258)
# 448 0.0013694522203877568
# predict (after training) 4 tensor(7.9260)
# 449 0.0013628682354465127
# predict (after training) 4 tensor(7.9261)
# 450 0.0013563298853114247
# predict (after training) 4 tensor(7.9263)
# 451 0.0013498136540874839
# predict (after training) 4 tensor(7.9265)
# 452 0.001343333744443953
# predict (after training) 4 tensor(7.9267)
# 453 0.0013368794461712241
# predict (after training) 4 tensor(7.9268)
# 454 0.0013304551830515265
# predict (after training) 4 tensor(7.9270)
# 455 0.0013240781845524907
# predict (after training) 4 tensor(7.9272)
# 456 0.0013177116634324193
# predict (after training) 4 tensor(7.9274)
# 457 0.0013113812310621142
# predict (after training) 4 tensor(7.9275)
# 458 0.0013050840934738517
# predict (after training) 4 tensor(7.9277)
# 459 0.0012988202506676316
# predict (after training) 4 tensor(7.9279)
# 460 0.0012925921473652124
# predict (after training) 4 tensor(7.9281)
# 461 0.0012863740557804704
# predict (after training) 4 tensor(7.9282)
# 462 0.0012802022974938154
# predict (after training) 4 tensor(7.9284)
# 463 0.0012740620877593756
# predict (after training) 4 tensor(7.9286)
# 464 0.001267933170311153
# predict (after training) 4 tensor(7.9288)
# 465 0.0012618511682376266
# predict (after training) 4 tensor(7.9289)
# 466 0.0012557896552607417
# predict (after training) 4 tensor(7.9291)
# 467 0.0012497593415901065
# predict (after training) 4 tensor(7.9293)
# 468 0.0012437531258910894
# predict (after training) 4 tensor(7.9294)
# 469 0.0012377803213894367
# predict (after training) 4 tensor(7.9296)
# 470 0.0012318405788391829
# predict (after training) 4 tensor(7.9298)
# 471 0.0012259316863492131
# predict (after training) 4 tensor(7.9299)
# 472 0.0012200450291857123
# predict (after training) 4 tensor(7.9301)
# 473 0.001214180956594646
# predict (after training) 4 tensor(7.9303)
# 474 0.0012083484325557947
# predict (after training) 4 tensor(7.9305)
# 475 0.0012025461765006185
# predict (after training) 4 tensor(7.9306)
# 476 0.0011967788450419903
# predict (after training) 4 tensor(7.9308)
# 477 0.0011910207103937864
# predict (after training) 4 tensor(7.9310)
# 478 0.0011853065807372332
# predict (after training) 4 tensor(7.9311)
# 479 0.0011796130565926433
# predict (after training) 4 tensor(7.9313)
# 480 0.0011739414185285568
# predict (after training) 4 tensor(7.9314)
# 481 0.0011683119228109717
# predict (after training) 4 tensor(7.9316)
# 482 0.0011626961641013622
# predict (after training) 4 tensor(7.9318)
# 483 0.0011571155628189445
# predict (after training) 4 tensor(7.9319)
# 484 0.0011515597580000758
# predict (after training) 4 tensor(7.9321)
# 485 0.0011460251407697797
# predict (after training) 4 tensor(7.9323)
# 486 0.0011405290570110083
# predict (after training) 4 tensor(7.9324)
# 487 0.0011350515997037292
# predict (after training) 4 tensor(7.9326)
# 488 0.001129601034335792
# predict (after training) 4 tensor(7.9328)
# 489 0.0011241690954193473
# predict (after training) 4 tensor(7.9329)
# 490 0.001118775107897818
# predict (after training) 4 tensor(7.9331)
# 491 0.001113401842303574
# predict (after training) 4 tensor(7.9332)
# 492 0.0011080604745075107
# predict (after training) 4 tensor(7.9334)
# 493 0.001102728652767837
# predict (after training) 4 tensor(7.9336)
# 494 0.001097437459975481
# predict (after training) 4 tensor(7.9337)
# 495 0.0010921778157353401
# predict (after training) 4 tensor(7.9339)
# 496 0.0010869276011362672
# predict (after training) 4 tensor(7.9340)
# 497 0.001081706490367651
# predict (after training) 4 tensor(7.9342)
# 498 0.0010765057522803545
# predict (after training) 4 tensor(7.9344)
# 499 0.0010713416850194335
# predict (after training) 4 tensor(7.9345)
