# %% [markdown]
# <a href="https://colab.research.google.com/github/Jina0202/PyTorchZeroToAll/blob/main/lec_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #lecture 5 Linear Regression in the PyTorch way
#
# ##1) Design model using class with Variables
#
# ##2) Construct loss and optimizer (select from PyTorch API)
#
# ##3) Training cycle (forward, backward, update)

# %%
###step 1
import torch
from torch.autograd import Variable
#data definition (3x1 MATRIX)
#3data, each data has 1 value x --> 일반화 nx1 MATRIX
#changed the form into MATRIX
x_data=Variable(torch.Tensor([[1.0],[2.0],[3.0]]))
y_data=Variable(torch.Tensor([[2.0],[4.0],[6.0]]))

class Model(torch.nn.Module): 
  #아무렇게나 이름 지음->Model, Model은 torch.nn.Module의 subclass
  #two function: __init__(), forward()
  def __init__(self):
    """
    In the constructor wew instantiate tow nn.Linear module
    """
    super(Model,self).__init__() #going to call super in it, do some initializaion task or creat element,some component
    self.linear=torch.nn.Linear(1,1) #make one linear block: (input,output) input, output is 1 bc x, y value is one each
  
  def forward(self,x): #not going to use our own weight, but use the block we initialized in it
    y_pred=self.linear(x)
    return y_pred
model=Model()
###step 2
#Construct our loss funtion and an Optimizer. The call to model.parameters
#in the SGD constructor will contain the learnable parameters of the two
#nn.Linear modules whoch are members of the model.
criterion=torch.nn.MSELoss(size_average=False) #라이브러리
optimizer=torch.optim.SGD(model.parameters(),lr=0.01) #알고리즘 compute data same times-앞 영상방식 zip들어간 방식보다 효율적 

###step 3
#Training loop
for epoch in range(500):
  #forward poss: compute predicted y by passing x to the model
  y_pred = model(x_data) #s_data: x_data=matrix

  #Compute and print loss
  loss=criterion(y_pred, y_data) #MSE계산
  print(epoch, loss.item()) 

  #Zero gradients, perform a backward pass, and update the weights
  optimizer.zero_grad() #initialize all the gradients
  loss.backward()
  optimizer.step() #update variable <</////////how??

  #After Training
  hour_var=Variable (torch.Tensor([[4.0]]))
  print("predict (after training)", 4, model.forward(hour_var).data[0][0])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 0 106.93785095214844
# predict (after training) 4 tensor(0.6593)
# 1 47.69679260253906
# predict (after training) 4 tensor(2.9485)
# 2 21.323049545288086
# predict (after training) 4 tensor(4.4771)
# 3 9.580916404724121
# predict (after training) 4 tensor(5.4980)
# 4 4.352380752563477
# predict (after training) 4 tensor(6.1803)
# 5 2.023531913757324
# predict (after training) 4 tensor(6.6366)
# 6 0.985558807849884
# predict (after training) 4 tensor(6.9421)
# 7 0.5222640037536621
# predict (after training) 4 tensor(7.1470)
# 8 0.31481873989105225
# predict (after training) 4 tensor(7.2848)
# 9 0.22128668427467346
# predict (after training) 4 tensor(7.3778)
# 10 0.17848296463489532
# predict (after training) 4 tensor(7.4409)
# 11 0.15827828645706177
# predict (after training) 4 tensor(7.4840)
# 12 0.14815089106559753
# predict (after training) 4 tensor(7.5138)
# 13 0.14252594113349915
# predict (after training) 4 tensor(7.5348)
# 14 0.13892143964767456
# predict (after training) 4 tensor(7.5497)
# 15 0.13623234629631042
# predict (after training) 4 tensor(7.5607)
# 16 0.13396592438220978
# predict (after training) 4 tensor(7.5691)
# 17 0.1319032907485962
# predict (after training) 4 tensor(7.5756)
# 18 0.12994679808616638
# predict (after training) 4 tensor(7.5810)
# 19 0.12805184721946716
# predict (after training) 4 tensor(7.5855)
# 20 0.12619933485984802
# predict (after training) 4 tensor(7.5895)
# 21 0.1243804395198822
# predict (after training) 4 tensor(7.5932)
# 22 0.12259034812450409
# predict (after training) 4 tensor(7.5966)
# 23 0.12082763761281967
# predict (after training) 4 tensor(7.5998)
# 24 0.11909071356058121
# predict (after training) 4 tensor(7.6029)
# 25 0.117378830909729
# predict (after training) 4 tensor(7.6059)
# 26 0.11569178104400635
# predict (after training) 4 tensor(7.6088)
# 27 0.11402908712625504
# predict (after training) 4 tensor(7.6117)
# 28 0.11239032447338104
# predict (after training) 4 tensor(7.6145)
# 29 0.11077505350112915
# predict (after training) 4 tensor(7.6173)
# 30 0.10918299108743668
# predict (after training) 4 tensor(7.6201)
# 31 0.10761398077011108
# predict (after training) 4 tensor(7.6229)
# 32 0.1060672476887703
# predict (after training) 4 tensor(7.6256)
# 33 0.10454297065734863
# predict (after training) 4 tensor(7.6283)
# 34 0.10304047167301178
# predict (after training) 4 tensor(7.6310)
# 35 0.1015595868229866
# predict (after training) 4 tensor(7.6337)
# 36 0.10009995102882385
# predict (after training) 4 tensor(7.6363)
# 37 0.09866157174110413
# predict (after training) 4 tensor(7.6389)
# 38 0.09724351018667221
# predict (after training) 4 tensor(7.6415)
# 39 0.09584598243236542
# predict (after training) 4 tensor(7.6441)
# 40 0.09446844458580017
# predict (after training) 4 tensor(7.6467)
# 41 0.0931108146905899
# predict (after training) 4 tensor(7.6492)
# 42 0.09177269786596298
# predict (after training) 4 tensor(7.6518)
# 43 0.0904538482427597
# predict (after training) 4 tensor(7.6543)
# 44 0.0891537070274353
# predict (after training) 4 tensor(7.6568)
# 45 0.08787254989147186
# predict (after training) 4 tensor(7.6592)
# 46 0.08660976588726044
# predict (after training) 4 tensor(7.6617)
# 47 0.0853649377822876
# predict (after training) 4 tensor(7.6641)
# 48 0.08413800597190857
# predict (after training) 4 tensor(7.6666)
# 49 0.08292894065380096
# predict (after training) 4 tensor(7.6690)
# 50 0.08173719793558121
# predict (after training) 4 tensor(7.6713)
# 51 0.08056246489286423
# predict (after training) 4 tensor(7.6737)
# 52 0.07940466701984406
# predict (after training) 4 tensor(7.6761)
# 53 0.07826338708400726
# predict (after training) 4 tensor(7.6784)
# 54 0.0771387368440628
# predict (after training) 4 tensor(7.6807)
# 55 0.07603007555007935
# predict (after training) 4 tensor(7.6830)
# 56 0.07493732124567032
# predict (after training) 4 tensor(7.6853)
# 57 0.07386042177677155
# predict (after training) 4 tensor(7.6876)
# 58 0.07279901951551437
# predict (after training) 4 tensor(7.6898)
# 59 0.07175274193286896
# predict (after training) 4 tensor(7.6921)
# 60 0.07072144001722336
# predict (after training) 4 tensor(7.6943)
# 61 0.06970518082380295
# predict (after training) 4 tensor(7.6965)
# 62 0.0687033161520958
# predict (after training) 4 tensor(7.6987)
# 63 0.06771596521139145
# predict (after training) 4 tensor(7.7009)
# 64 0.06674282252788544
# predict (after training) 4 tensor(7.7030)
# 65 0.06578362733125687
# predict (after training) 4 tensor(7.7052)
# 66 0.0648382306098938
# predict (after training) 4 tensor(7.7073)
# 67 0.06390638649463654
# predict (after training) 4 tensor(7.7094)
# 68 0.06298792362213135
# predict (after training) 4 tensor(7.7115)
# 69 0.06208264082670212
# predict (after training) 4 tensor(7.7136)
# 70 0.061190418899059296
# predict (after training) 4 tensor(7.7156)
# 71 0.06031109765172005
# predict (after training) 4 tensor(7.7177)
# 72 0.05944424122571945
# predict (after training) 4 tensor(7.7197)
# 73 0.05858998745679855
# predict (after training) 4 tensor(7.7217)
# 74 0.057747967541217804
# predict (after training) 4 tensor(7.7238)
# 75 0.056918106973171234
# predict (after training) 4 tensor(7.7257)
# 76 0.05609993636608124
# predict (after training) 4 tensor(7.7277)
# 77 0.05529376119375229
# predict (after training) 4 tensor(7.7297)
# 78 0.05449911952018738
# predict (after training) 4 tensor(7.7316)
# 79 0.05371594429016113
# predict (after training) 4 tensor(7.7336)
# 80 0.05294393375515938
# predict (after training) 4 tensor(7.7355)
# 81 0.05218306928873062
# predict (after training) 4 tensor(7.7374)
# 82 0.0514330230653286
# predict (after training) 4 tensor(7.7393)
# 83 0.050693877041339874
# predict (after training) 4 tensor(7.7412)
# 84 0.049965277314186096
# predict (after training) 4 tensor(7.7430)
# 85 0.04924730211496353
# predict (after training) 4 tensor(7.7449)
# 86 0.048539552837610245
# predict (after training) 4 tensor(7.7467)
# 87 0.04784190654754639
# predict (after training) 4 tensor(7.7486)
# 88 0.04715434089303017
# predict (after training) 4 tensor(7.7504)
# 89 0.04647660255432129
# predict (after training) 4 tensor(7.7522)
# 90 0.04580869525671005
# predict (after training) 4 tensor(7.7540)
# 91 0.045150384306907654
# predict (after training) 4 tensor(7.7557)
# 92 0.04450145363807678
# predict (after training) 4 tensor(7.7575)
# 93 0.04386197775602341
# predict (after training) 4 tensor(7.7592)
# 94 0.04323164373636246
# predict (after training) 4 tensor(7.7610)
# 95 0.04261017218232155
# predict (after training) 4 tensor(7.7627)
# 96 0.04199783504009247
# predict (after training) 4 tensor(7.7644)
# 97 0.041394345462322235
# predict (after training) 4 tensor(7.7661)
# 98 0.04079952836036682
# predict (after training) 4 tensor(7.7678)
# 99 0.04021308943629265
# predict (after training) 4 tensor(7.7695)
# 100 0.03963514044880867
# predict (after training) 4 tensor(7.7711)
# 101 0.03906550258398056
# predict (after training) 4 tensor(7.7728)
# 102 0.03850410878658295
# predict (after training) 4 tensor(7.7744)
# 103 0.03795080631971359
# predict (after training) 4 tensor(7.7761)
# 104 0.03740537911653519
# predict (after training) 4 tensor(7.7777)
# 105 0.03686777129769325
# predict (after training) 4 tensor(7.7793)
# 106 0.03633788973093033
# predict (after training) 4 tensor(7.7809)
# 107 0.03581566363573074
# predict (after training) 4 tensor(7.7824)
# 108 0.035300977528095245
# predict (after training) 4 tensor(7.7840)
# 109 0.034793637692928314
# predict (after training) 4 tensor(7.7856)
# 110 0.034293681383132935
# predict (after training) 4 tensor(7.7871)
# 111 0.03380070626735687
# predict (after training) 4 tensor(7.7887)
# 112 0.03331495821475983
# predict (after training) 4 tensor(7.7902)
# 113 0.03283616900444031
# predict (after training) 4 tensor(7.7917)
# 114 0.03236428648233414
# predict (after training) 4 tensor(7.7932)
# 115 0.03189922869205475
# predict (after training) 4 tensor(7.7947)
# 116 0.031440719962120056
# predict (after training) 4 tensor(7.7962)
# 117 0.03098878636956215
# predict (after training) 4 tensor(7.7976)
# 118 0.030543478205800056
# predict (after training) 4 tensor(7.7991)
# 119 0.03010449931025505
# predict (after training) 4 tensor(7.8005)
# 120 0.0296719241887331
# predict (after training) 4 tensor(7.8020)
# 121 0.02924541011452675
# predict (after training) 4 tensor(7.8034)
# 122 0.028825175017118454
# predict (after training) 4 tensor(7.8048)
# 123 0.028410928323864937
# predict (after training) 4 tensor(7.8062)
# 124 0.028002571314573288
# predict (after training) 4 tensor(7.8076)
# 125 0.027600126340985298
# predict (after training) 4 tensor(7.8090)
# 126 0.027203451842069626
# predict (after training) 4 tensor(7.8104)
# 127 0.02681250497698784
# predict (after training) 4 tensor(7.8118)
# 128 0.026427090167999268
# predict (after training) 4 tensor(7.8131)
# 129 0.02604738436639309
# predict (after training) 4 tensor(7.8145)
# 130 0.025673091411590576
# predict (after training) 4 tensor(7.8158)
# 131 0.025304123759269714
# predict (after training) 4 tensor(7.8171)
# 132 0.024940425530076027
# predict (after training) 4 tensor(7.8185)
# 133 0.024581950157880783
# predict (after training) 4 tensor(7.8198)
# 134 0.02422873117029667
# predict (after training) 4 tensor(7.8211)
# 135 0.02388046681880951
# predict (after training) 4 tensor(7.8224)
# 136 0.02353733591735363
# predict (after training) 4 tensor(7.8236)
# 137 0.023199060931801796
# predict (after training) 4 tensor(7.8249)
# 138 0.022865530103445053
# predict (after training) 4 tensor(7.8262)
# 139 0.02253696322441101
# predict (after training) 4 tensor(7.8274)
# 140 0.022213105112314224
# predict (after training) 4 tensor(7.8287)
# 141 0.021893879398703575
# predict (after training) 4 tensor(7.8299)
# 142 0.02157924696803093
# predict (after training) 4 tensor(7.8311)
# 143 0.02126908488571644
# predict (after training) 4 tensor(7.8324)
# 144 0.020963475108146667
# predict (after training) 4 tensor(7.8336)
# 145 0.020662160590291023
# predict (after training) 4 tensor(7.8348)
# 146 0.02036520652472973
# predict (after training) 4 tensor(7.8360)
# 147 0.02007252722978592
# predict (after training) 4 tensor(7.8371)
# 148 0.019784078001976013
# predict (after training) 4 tensor(7.8383)
# 149 0.019499696791172028
# predict (after training) 4 tensor(7.8395)
# 150 0.019219420850276947
# predict (after training) 4 tensor(7.8406)
# 151 0.018943216651678085
# predict (after training) 4 tensor(7.8418)
# 152 0.018670955672860146
# predict (after training) 4 tensor(7.8429)
# 153 0.01840267702937126
# predict (after training) 4 tensor(7.8441)
# 154 0.018138237297534943
# predict (after training) 4 tensor(7.8452)
# 155 0.01787753775715828
# predict (after training) 4 tensor(7.8463)
# 156 0.017620591446757317
# predict (after training) 4 tensor(7.8474)
# 157 0.01736738160252571
# predict (after training) 4 tensor(7.8485)
# 158 0.01711777038872242
# predict (after training) 4 tensor(7.8496)
# 159 0.016871705651283264
# predict (after training) 4 tensor(7.8507)
# 160 0.016629278659820557
# predict (after training) 4 tensor(7.8518)
# 161 0.01639028824865818
# predict (after training) 4 tensor(7.8528)
# 162 0.01615472137928009
# predict (after training) 4 tensor(7.8539)
# 163 0.01592256873846054
# predict (after training) 4 tensor(7.8549)
# 164 0.015693780034780502
# predict (after training) 4 tensor(7.8560)
# 165 0.015468213707208633
# predict (after training) 4 tensor(7.8570)
# 166 0.015245904214680195
# predict (after training) 4 tensor(7.8581)
# 167 0.015026828274130821
# predict (after training) 4 tensor(7.8591)
# 168 0.014810845255851746
# predict (after training) 4 tensor(7.8601)
# 169 0.01459793746471405
# predict (after training) 4 tensor(7.8611)
# 170 0.014388179406523705
# predict (after training) 4 tensor(7.8621)
# 171 0.014181381091475487
# predict (after training) 4 tensor(7.8631)
# 172 0.013977578841149807
# predict (after training) 4 tensor(7.8641)
# 173 0.013776744715869427
# predict (after training) 4 tensor(7.8651)
# 174 0.013578707352280617
# predict (after training) 4 tensor(7.8660)
# 175 0.013383622281253338
# predict (after training) 4 tensor(7.8670)
# 176 0.013191258534789085
# predict (after training) 4 tensor(7.8680)
# 177 0.013001699931919575
# predict (after training) 4 tensor(7.8689)
# 178 0.01281476765871048
# predict (after training) 4 tensor(7.8699)
# 179 0.012630635872483253
# predict (after training) 4 tensor(7.8708)
# 180 0.012449095025658607
# predict (after training) 4 tensor(7.8717)
# 181 0.012270193547010422
# predict (after training) 4 tensor(7.8727)
# 182 0.012093855068087578
# predict (after training) 4 tensor(7.8736)
# 183 0.011920022778213024
# predict (after training) 4 tensor(7.8745)
# 184 0.011748772114515305
# predict (after training) 4 tensor(7.8754)
# 185 0.011579888872802258
# predict (after training) 4 tensor(7.8763)
# 186 0.011413437314331532
# predict (after training) 4 tensor(7.8772)
# 187 0.011249430477619171
# predict (after training) 4 tensor(7.8781)
# 188 0.011087751016020775
# predict (after training) 4 tensor(7.8790)
# 189 0.010928370989859104
# predict (after training) 4 tensor(7.8798)
# 190 0.010771381668746471
# predict (after training) 4 tensor(7.8807)
# 191 0.010616541840136051
# predict (after training) 4 tensor(7.8816)
# 192 0.01046394556760788
# predict (after training) 4 tensor(7.8824)
# 193 0.010313589125871658
# predict (after training) 4 tensor(7.8833)
# 194 0.010165322571992874
# predict (after training) 4 tensor(7.8841)
# 195 0.010019276291131973
# predict (after training) 4 tensor(7.8849)
# 196 0.009875268675386906
# predict (after training) 4 tensor(7.8858)
# 197 0.00973338820040226
# predict (after training) 4 tensor(7.8866)
# 198 0.009593496099114418
# predict (after training) 4 tensor(7.8874)
# 199 0.009455646388232708
# predict (after training) 4 tensor(7.8882)
# 200 0.009319714270532131
# predict (after training) 4 tensor(7.8890)
# 201 0.009185758419334888
# predict (after training) 4 tensor(7.8898)
# 202 0.00905377883464098
# predict (after training) 4 tensor(7.8906)
# 203 0.008923638612031937
# predict (after training) 4 tensor(7.8914)
# 204 0.00879538431763649
# predict (after training) 4 tensor(7.8922)
# 205 0.008669000118970871
# predict (after training) 4 tensor(7.8930)
# 206 0.008544407784938812
# predict (after training) 4 tensor(7.8937)
# 207 0.008421633392572403
# predict (after training) 4 tensor(7.8945)
# 208 0.008300606161355972
# predict (after training) 4 tensor(7.8953)
# 209 0.008181296288967133
# predict (after training) 4 tensor(7.8960)
# 210 0.008063696324825287
# predict (after training) 4 tensor(7.8968)
# 211 0.007947859354317188
# predict (after training) 4 tensor(7.8975)
# 212 0.007833601906895638
# predict (after training) 4 tensor(7.8983)
# 213 0.00772098358720541
# predict (after training) 4 tensor(7.8990)
# 214 0.007610013242810965
# predict (after training) 4 tensor(7.8997)
# 215 0.00750068761408329
# predict (after training) 4 tensor(7.9004)
# 216 0.0073928916826844215
# predict (after training) 4 tensor(7.9012)
# 217 0.007286605890840292
# predict (after training) 4 tensor(7.9019)
# 218 0.007181918248534203
# predict (after training) 4 tensor(7.9026)
# 219 0.007078671827912331
# predict (after training) 4 tensor(7.9033)
# 220 0.006976979319006205
# predict (after training) 4 tensor(7.9040)
# 221 0.006876669358462095
# predict (after training) 4 tensor(7.9047)
# 222 0.0067778658121824265
# predict (after training) 4 tensor(7.9054)
# 223 0.006680456921458244
# predict (after training) 4 tensor(7.9060)
# 224 0.006584455259144306
# predict (after training) 4 tensor(7.9067)
# 225 0.006489809136837721
# predict (after training) 4 tensor(7.9074)
# 226 0.006396555341780186
# predict (after training) 4 tensor(7.9081)
# 227 0.006304595153778791
# predict (after training) 4 tensor(7.9087)
# 228 0.00621398352086544
# predict (after training) 4 tensor(7.9094)
# 229 0.00612469669431448
# predict (after training) 4 tensor(7.9100)
# 230 0.006036706268787384
# predict (after training) 4 tensor(7.9107)
# 231 0.005949927493929863
# predict (after training) 4 tensor(7.9113)
# 232 0.0058643994852900505
# predict (after training) 4 tensor(7.9120)
# 233 0.005780127830803394
# predict (after training) 4 tensor(7.9126)
# 234 0.0056970445439219475
# predict (after training) 4 tensor(7.9132)
# 235 0.0056151943281292915
# predict (after training) 4 tensor(7.9139)
# 236 0.005534473806619644
# predict (after training) 4 tensor(7.9145)
# 237 0.005454921163618565
# predict (after training) 4 tensor(7.9151)
# 238 0.005376515910029411
# predict (after training) 4 tensor(7.9157)
# 239 0.005299287848174572
# predict (after training) 4 tensor(7.9163)
# 240 0.005223109852522612
# predict (after training) 4 tensor(7.9169)
# 241 0.0051480503752827644
# predict (after training) 4 tensor(7.9175)
# 242 0.005074056796729565
# predict (after training) 4 tensor(7.9181)
# 243 0.005001124460250139
# predict (after training) 4 tensor(7.9187)
# 244 0.004929267801344395
# predict (after training) 4 tensor(7.9193)
# 245 0.004858392756432295
# predict (after training) 4 tensor(7.9199)
# 246 0.004788585938513279
# predict (after training) 4 tensor(7.9205)
# 247 0.004719799384474754
# predict (after training) 4 tensor(7.9210)
# 248 0.004651959519833326
# predict (after training) 4 tensor(7.9216)
# 249 0.004585110116750002
# predict (after training) 4 tensor(7.9222)
# 250 0.004519213922321796
# predict (after training) 4 tensor(7.9227)
# 251 0.004454248119145632
# predict (after training) 4 tensor(7.9233)
# 252 0.0043902271427214146
# predict (after training) 4 tensor(7.9238)
# 253 0.004327143542468548
# predict (after training) 4 tensor(7.9244)
# 254 0.0042649684473872185
# predict (after training) 4 tensor(7.9249)
# 255 0.0042036427184939384
# predict (after training) 4 tensor(7.9255)
# 256 0.004143274389207363
# predict (after training) 4 tensor(7.9260)
# 257 0.00408368743956089
# predict (after training) 4 tensor(7.9265)
# 258 0.004025008529424667
# predict (after training) 4 tensor(7.9271)
# 259 0.0039671640843153
# predict (after training) 4 tensor(7.9276)
# 260 0.003910178318619728
# predict (after training) 4 tensor(7.9281)
# 261 0.003853951580822468
# predict (after training) 4 tensor(7.9286)
# 262 0.003798576071858406
# predict (after training) 4 tensor(7.9292)
# 263 0.003744010580703616
# predict (after training) 4 tensor(7.9297)
# 264 0.0036901577841490507
# predict (after training) 4 tensor(7.9302)
# 265 0.00363714387640357
# predict (after training) 4 tensor(7.9307)
# 266 0.003584872232750058
# predict (after training) 4 tensor(7.9312)
# 267 0.0035333381965756416
# predict (after training) 4 tensor(7.9317)
# 268 0.003482565050944686
# predict (after training) 4 tensor(7.9322)
# 269 0.0034324931912124157
# predict (after training) 4 tensor(7.9327)
# 270 0.003383179660886526
# predict (after training) 4 tensor(7.9331)
# 271 0.003334555309265852
# predict (after training) 4 tensor(7.9336)
# 272 0.0032866294495761395
# predict (after training) 4 tensor(7.9341)
# 273 0.003239431418478489
# predict (after training) 4 tensor(7.9346)
# 274 0.0031928569078445435
# predict (after training) 4 tensor(7.9350)
# 275 0.003146962495520711
# predict (after training) 4 tensor(7.9355)
# 276 0.0031017432920634747
# predict (after training) 4 tensor(7.9360)
# 277 0.0030571569222956896
# predict (after training) 4 tensor(7.9364)
# 278 0.003013209206983447
# predict (after training) 4 tensor(7.9369)
# 279 0.0029699092265218496
# predict (after training) 4 tensor(7.9374)
# 280 0.0029272560495883226
# predict (after training) 4 tensor(7.9378)
# 281 0.0028851612005382776
# predict (after training) 4 tensor(7.9383)
# 282 0.002843697089701891
# predict (after training) 4 tensor(7.9387)
# 283 0.002802834380418062
# predict (after training) 4 tensor(7.9391)
# 284 0.002762545831501484
# predict (after training) 4 tensor(7.9396)
# 285 0.0027228579856455326
# predict (after training) 4 tensor(7.9400)
# 286 0.0026837047189474106
# predict (after training) 4 tensor(7.9404)
# 287 0.002645154483616352
# predict (after training) 4 tensor(7.9409)
# 288 0.002607121132314205
# predict (after training) 4 tensor(7.9413)
# 289 0.002569657750427723
# predict (after training) 4 tensor(7.9417)
# 290 0.0025327405892312527
# predict (after training) 4 tensor(7.9421)
# 291 0.0024963344912976027
# predict (after training) 4 tensor(7.9426)
# 292 0.0024604457430541515
# predict (after training) 4 tensor(7.9430)
# 293 0.0024251032155007124
# predict (after training) 4 tensor(7.9434)
# 294 0.002390269422903657
# predict (after training) 4 tensor(7.9438)
# 295 0.0023559133987873793
# predict (after training) 4 tensor(7.9442)
# 296 0.0023220358416438103
# predict (after training) 4 tensor(7.9446)
# 297 0.002288659568876028
# predict (after training) 4 tensor(7.9450)
# 298 0.0022557952906936407
# predict (after training) 4 tensor(7.9454)
# 299 0.002223366405814886
# predict (after training) 4 tensor(7.9458)
# 300 0.0021914225071668625
# predict (after training) 4 tensor(7.9462)
# 301 0.002159885363653302
# predict (after training) 4 tensor(7.9466)
# 302 0.0021288800053298473
# predict (after training) 4 tensor(7.9470)
# 303 0.0020982748828828335
# predict (after training) 4 tensor(7.9473)
# 304 0.0020681130699813366
# predict (after training) 4 tensor(7.9477)
# 305 0.002038403181359172
# predict (after training) 4 tensor(7.9481)
# 306 0.0020091040059924126
# predict (after training) 4 tensor(7.9485)
# 307 0.0019802290480583906
# predict (after training) 4 tensor(7.9488)
# 308 0.0019517506007105112
# predict (after training) 4 tensor(7.9492)
# 309 0.0019237155793234706
# predict (after training) 4 tensor(7.9496)
# 310 0.0018960655434057117
# predict (after training) 4 tensor(7.9499)
# 311 0.0018688294803723693
# predict (after training) 4 tensor(7.9503)
# 312 0.0018419499974697828
# predict (after training) 4 tensor(7.9507)
# 313 0.00181549321860075
# predict (after training) 4 tensor(7.9510)
# 314 0.0017893902258947492
# predict (after training) 4 tensor(7.9514)
# 315 0.0017636788543313742
# predict (after training) 4 tensor(7.9517)
# 316 0.0017383306985720992
# predict (after training) 4 tensor(7.9521)
# 317 0.0017133534420281649
# predict (after training) 4 tensor(7.9524)
# 318 0.001688729040324688
# predict (after training) 4 tensor(7.9528)
# 319 0.0016644633142277598
# predict (after training) 4 tensor(7.9531)
# 320 0.0016405474161729217
# predict (after training) 4 tensor(7.9534)
# 321 0.001616963534615934
# predict (after training) 4 tensor(7.9538)
# 322 0.0015937199350446463
# predict (after training) 4 tensor(7.9541)
# 323 0.0015708219725638628
# predict (after training) 4 tensor(7.9544)
# 324 0.0015482405433431268
# predict (after training) 4 tensor(7.9548)
# 325 0.0015259931096807122
# predict (after training) 4 tensor(7.9551)
# 326 0.0015040601138025522
# predict (after training) 4 tensor(7.9554)
# 327 0.0014824492391198874
# predict (after training) 4 tensor(7.9557)
# 328 0.0014611324295401573
# predict (after training) 4 tensor(7.9561)
# 329 0.0014401598600670695
# predict (after training) 4 tensor(7.9564)
# 330 0.0014194417744874954
# predict (after training) 4 tensor(7.9567)
# 331 0.0013990392908453941
# predict (after training) 4 tensor(7.9570)
# 332 0.0013789440272375941
# predict (after training) 4 tensor(7.9573)
# 333 0.001359118614345789
# predict (after training) 4 tensor(7.9576)
# 334 0.001339572947472334
# predict (after training) 4 tensor(7.9579)
# 335 0.0013203357812017202
# predict (after training) 4 tensor(7.9582)
# 336 0.00130136136431247
# predict (after training) 4 tensor(7.9585)
# 337 0.0012826659949496388
# predict (after training) 4 tensor(7.9588)
# 338 0.0012642154470086098
# predict (after training) 4 tensor(7.9591)
# 339 0.0012460503494367003
# predict (after training) 4 tensor(7.9594)
# 340 0.0012281594099476933
# predict (after training) 4 tensor(7.9597)
# 341 0.0012104989727959037
# predict (after training) 4 tensor(7.9600)
# 342 0.0011930989567190409
# predict (after training) 4 tensor(7.9603)
# 343 0.0011759445769712329
# predict (after training) 4 tensor(7.9606)
# 344 0.0011590509675443172
# predict (after training) 4 tensor(7.9609)
# 345 0.0011423976393416524
# predict (after training) 4 tensor(7.9611)
# 346 0.0011259778402745724
# predict (after training) 4 tensor(7.9614)
# 347 0.0011097951792180538
# predict (after training) 4 tensor(7.9617)
# 348 0.0010938448831439018
# predict (after training) 4 tensor(7.9620)
# 349 0.001078139990568161
# predict (after training) 4 tensor(7.9623)
# 350 0.0010626452276483178
# predict (after training) 4 tensor(7.9625)
# 351 0.0010473586153239012
# predict (after training) 4 tensor(7.9628)
# 352 0.0010323228780180216
# predict (after training) 4 tensor(7.9631)
# 353 0.0010174718918278813
# predict (after training) 4 tensor(7.9633)
# 354 0.0010028574615716934
# predict (after training) 4 tensor(7.9636)
# 355 0.0009884382598102093
# predict (after training) 4 tensor(7.9639)
# 356 0.000974237744230777
# predict (after training) 4 tensor(7.9641)
# 357 0.0009602283826097846
# predict (after training) 4 tensor(7.9644)
# 358 0.0009464366012252867
# predict (after training) 4 tensor(7.9646)
# 359 0.0009328388259746134
# predict (after training) 4 tensor(7.9649)
# 360 0.0009194292942993343
# predict (after training) 4 tensor(7.9651)
# 361 0.0009062096942216158
# predict (after training) 4 tensor(7.9654)
# 362 0.0008931743213906884
# predict (after training) 4 tensor(7.9656)
# 363 0.0008803387172520161
# predict (after training) 4 tensor(7.9659)
# 364 0.0008676867000758648
# predict (after training) 4 tensor(7.9661)
# 365 0.0008552300860174
# predict (after training) 4 tensor(7.9664)
# 366 0.000842937792185694
# predict (after training) 4 tensor(7.9666)
# 367 0.0008308182004839182
# predict (after training) 4 tensor(7.9669)
# 368 0.0008188746287487447
# predict (after training) 4 tensor(7.9671)
# 369 0.0008071067277342081
# predict (after training) 4 tensor(7.9673)
# 370 0.0007955075707286596
# predict (after training) 4 tensor(7.9676)
# 371 0.000784078729338944
# predict (after training) 4 tensor(7.9678)
# 372 0.0007728149648755789
# predict (after training) 4 tensor(7.9680)
# 373 0.0007617065566591918
# predict (after training) 4 tensor(7.9683)
# 374 0.0007507517584599555
# predict (after training) 4 tensor(7.9685)
# 375 0.0007399697788059711
# predict (after training) 4 tensor(7.9687)
# 376 0.0007293362868949771
# predict (after training) 4 tensor(7.9690)
# 377 0.0007188468589447439
# predict (after training) 4 tensor(7.9692)
# 378 0.0007085185497999191
# predict (after training) 4 tensor(7.9694)
# 379 0.0006983418134041131
# predict (after training) 4 tensor(7.9696)
# 380 0.0006882981397211552
# predict (after training) 4 tensor(7.9698)
# 381 0.0006784150609746575
# predict (after training) 4 tensor(7.9701)
# 382 0.0006686620763503015
# predict (after training) 4 tensor(7.9703)
# 383 0.0006590439006686211
# predict (after training) 4 tensor(7.9705)
# 384 0.0006495873676612973
# predict (after training) 4 tensor(7.9707)
# 385 0.0006402387516573071
# predict (after training) 4 tensor(7.9709)
# 386 0.0006310499738901854
# predict (after training) 4 tensor(7.9711)
# 387 0.0006219769711606205
# predict (after training) 4 tensor(7.9713)
# 388 0.0006130487890914083
# predict (after training) 4 tensor(7.9715)
# 389 0.0006042280583642423
# predict (after training) 4 tensor(7.9717)
# 390 0.0005955450469627976
# predict (after training) 4 tensor(7.9719)
# 391 0.0005869966698810458
# predict (after training) 4 tensor(7.9721)
# 392 0.0005785422399640083
# predict (after training) 4 tensor(7.9724)
# 393 0.0005702352500520647
# predict (after training) 4 tensor(7.9725)
# 394 0.0005620379815809429
# predict (after training) 4 tensor(7.9727)
# 395 0.0005539589328691363
# predict (after training) 4 tensor(7.9729)
# 396 0.000546002178452909
# predict (after training) 4 tensor(7.9731)
# 397 0.0005381501978263259
# predict (after training) 4 tensor(7.9733)
# 398 0.0005304180085659027
# predict (after training) 4 tensor(7.9735)
# 399 0.0005227896617725492
# predict (after training) 4 tensor(7.9737)
# 400 0.0005152745870873332
# predict (after training) 4 tensor(7.9739)
# 401 0.0005078742397017777
# predict (after training) 4 tensor(7.9741)
# 402 0.0005005781422369182
# predict (after training) 4 tensor(7.9743)
# 403 0.0004933813470415771
# predict (after training) 4 tensor(7.9745)
# 404 0.0004862828063778579
# predict (after training) 4 tensor(7.9746)
# 405 0.00047930568689480424
# predict (after training) 4 tensor(7.9748)
# 406 0.0004724131431430578
# predict (after training) 4 tensor(7.9750)
# 407 0.00046561946510337293
# predict (after training) 4 tensor(7.9752)
# 408 0.0004589309683069587
# predict (after training) 4 tensor(7.9754)
# 409 0.0004523379320744425
# predict (after training) 4 tensor(7.9756)
# 410 0.00044583677663467824
# predict (after training) 4 tensor(7.9757)
# 411 0.00043943020864389837
# predict (after training) 4 tensor(7.9759)
# 412 0.00043311112676747143
# predict (after training) 4 tensor(7.9761)
# 413 0.00042689667316153646
# predict (after training) 4 tensor(7.9762)
# 414 0.00042074863449670374
# predict (after training) 4 tensor(7.9764)
# 415 0.00041470080032013357
# predict (after training) 4 tensor(7.9766)
# 416 0.0004087508423253894
# predict (after training) 4 tensor(7.9768)
# 417 0.0004028788534924388
# predict (after training) 4 tensor(7.9769)
# 418 0.0003970841644331813
# predict (after training) 4 tensor(7.9771)
# 419 0.0003913877881132066
# predict (after training) 4 tensor(7.9773)
# 420 0.0003857542760670185
# predict (after training) 4 tensor(7.9774)
# 421 0.0003802171559073031
# predict (after training) 4 tensor(7.9776)
# 422 0.0003747380687855184
# predict (after training) 4 tensor(7.9777)
# 423 0.0003693601756822318
# predict (after training) 4 tensor(7.9779)
# 424 0.0003640434006229043
# predict (after training) 4 tensor(7.9781)
# 425 0.00035881466465070844
# predict (after training) 4 tensor(7.9782)
# 426 0.0003536631411407143
# predict (after training) 4 tensor(7.9784)
# 427 0.0003485836205072701
# predict (after training) 4 tensor(7.9785)
# 428 0.0003435624239500612
# predict (after training) 4 tensor(7.9787)
# 429 0.0003386279277037829
# predict (after training) 4 tensor(7.9788)
# 430 0.0003337694506626576
# predict (after training) 4 tensor(7.9790)
# 431 0.0003289671731181443
# predict (after training) 4 tensor(7.9792)
# 432 0.000324240536428988
# predict (after training) 4 tensor(7.9793)
# 433 0.000319578277412802
# predict (after training) 4 tensor(7.9794)
# 434 0.00031498793396167457
# predict (after training) 4 tensor(7.9796)
# 435 0.0003104625502601266
# predict (after training) 4 tensor(7.9797)
# 436 0.000305999448755756
# predict (after training) 4 tensor(7.9799)
# 437 0.0003016009577549994
# predict (after training) 4 tensor(7.9800)
# 438 0.00029726335196755826
# predict (after training) 4 tensor(7.9802)
# 439 0.00029300095047801733
# predict (after training) 4 tensor(7.9803)
# 440 0.0002887772861868143
# predict (after training) 4 tensor(7.9805)
# 441 0.00028463327907957137
# predict (after training) 4 tensor(7.9806)
# 442 0.0002805445692501962
# predict (after training) 4 tensor(7.9807)
# 443 0.0002765115350484848
# predict (after training) 4 tensor(7.9809)
# 444 0.00027253746520727873
# predict (after training) 4 tensor(7.9810)
# 445 0.000268622679868713
# predict (after training) 4 tensor(7.9812)
# 446 0.0002647541696205735
# predict (after training) 4 tensor(7.9813)
# 447 0.0002609503280837089
# predict (after training) 4 tensor(7.9814)
# 448 0.000257208535913378
# predict (after training) 4 tensor(7.9816)
# 449 0.00025350856594741344
# predict (after training) 4 tensor(7.9817)
# 450 0.0002498629910405725
# predict (after training) 4 tensor(7.9818)
# 451 0.00024627664242871106
# predict (after training) 4 tensor(7.9820)
# 452 0.00024273798044305295
# predict (after training) 4 tensor(7.9821)
# 453 0.000239251006860286
# predict (after training) 4 tensor(7.9822)
# 454 0.00023581334971822798
# predict (after training) 4 tensor(7.9823)
# 455 0.00023241742746904492
# predict (after training) 4 tensor(7.9825)
# 456 0.00022907604579813778
# predict (after training) 4 tensor(7.9826)
# 457 0.00022578856442123652
# predict (after training) 4 tensor(7.9827)
# 458 0.0002225422067567706
# predict (after training) 4 tensor(7.9829)
# 459 0.0002193434484070167
# predict (after training) 4 tensor(7.9830)
# 460 0.00021619521430693567
# predict (after training) 4 tensor(7.9831)
# 461 0.00021308416035026312
# predict (after training) 4 tensor(7.9832)
# 462 0.00021001757704652846
# predict (after training) 4 tensor(7.9833)
# 463 0.00020699997548945248
# predict (after training) 4 tensor(7.9835)
# 464 0.00020403077360242605
# predict (after training) 4 tensor(7.9836)
# 465 0.00020109294564463198
# predict (after training) 4 tensor(7.9837)
# 466 0.00019820587476715446
# predict (after training) 4 tensor(7.9838)
# 467 0.00019535351020749658
# predict (after training) 4 tensor(7.9839)
# 468 0.00019255327060818672
# predict (after training) 4 tensor(7.9840)
# 469 0.000189782862435095
# predict (after training) 4 tensor(7.9842)
# 470 0.0001870571868494153
# predict (after training) 4 tensor(7.9843)
# 471 0.00018436936079524457
# predict (after training) 4 tensor(7.9844)
# 472 0.00018171902047470212
# predict (after training) 4 tensor(7.9845)
# 473 0.00017910890164785087
# predict (after training) 4 tensor(7.9846)
# 474 0.00017653076793067157
# predict (after training) 4 tensor(7.9847)
# 475 0.00017398977070115507
# predict (after training) 4 tensor(7.9848)
# 476 0.00017149381164927036
# predict (after training) 4 tensor(7.9849)
# 477 0.0001690279896138236
# predict (after training) 4 tensor(7.9851)
# 478 0.0001666002644924447
# predict (after training) 4 tensor(7.9852)
# 479 0.0001642102433834225
# predict (after training) 4 tensor(7.9853)
# 480 0.00016184564447030425
# predict (after training) 4 tensor(7.9854)
# 481 0.00015952165995258838
# predict (after training) 4 tensor(7.9855)
# 482 0.00015723126125521958
# predict (after training) 4 tensor(7.9856)
# 483 0.00015497190179303288
# predict (after training) 4 tensor(7.9857)
# 484 0.0001527418353362009
# predict (after training) 4 tensor(7.9858)
# 485 0.00015055216499604285
# predict (after training) 4 tensor(7.9859)
# 486 0.0001483811647631228
# predict (after training) 4 tensor(7.9860)
# 487 0.00014625053154304624
# predict (after training) 4 tensor(7.9861)
# 488 0.0001441443746443838
# predict (after training) 4 tensor(7.9862)
# 489 0.00014207637286745012
# predict (after training) 4 tensor(7.9863)
# 490 0.00014003776595927775
# predict (after training) 4 tensor(7.9864)
# 491 0.00013802411558572203
# predict (after training) 4 tensor(7.9865)
# 492 0.00013603593106381595
# predict (after training) 4 tensor(7.9866)
# 493 0.00013407763617578894
# predict (after training) 4 tensor(7.9867)
# 494 0.0001321562594966963
# predict (after training) 4 tensor(7.9868)
# 495 0.0001302547170780599
# predict (after training) 4 tensor(7.9869)
# 496 0.00012838673137594014
# predict (after training) 4 tensor(7.9870)
# 497 0.0001265427126782015
# predict (after training) 4 tensor(7.9871)
# 498 0.0001247217587660998
# predict (after training) 4 tensor(7.9872)
# 499 0.00012292753672227263
# predict (after training) 4 tensor(7.9873)
