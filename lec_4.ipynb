# %% [markdown]
# <a href="https://colab.research.google.com/github/Jina0202/PyTorchZeroToAll/blob/main/lec_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #lecture 5 Linear Regression in the PyTorch way
#
# ##1) Design model using class with Variables
#
# ##2) Construct loss and optimizer (select from PyTorch API)
#
# ##3) Training cycle (forward, backward, update)

# %%
###step 1
import torch
from torch.autograd import Variable
#data definition (3x1 MATRIX)
#3data, each data has 1 value x --> 일반화 nx1 MATRIX
#changed the form into MATRIX
x_data=Variable(torch.Tensor([[1.0],[2.0],[3.0]]))
y_data=Variable(torch.Tensor([[2.0],[4.0],[6.0]]))

class Model(torch.nn.Module): 
  #아무렇게나 이름 지음->Model, Model은 torch.nn.Module의 subclass
  #two function: __init__(), forward()
  def __init__(self):
    """
    In the constructor wew instantiate tow nn.Linear module
    """
    super(Model,self).__init__() #going to call super in it, do some initializaion task or creat element,some component
    self.linear=torch.nn.Linear(1,1) #make one linear block: (input,output) input, output is 1 bc x, y value is one each
  
  def forward(self,x): #not going to use our own weight, but use the block we initialized in it
    y_pred=self.linear(x)
    return y_pred
model=Model()
###step 2
#Construct our loss funtion and an Optimizer. The call to model.parameters
#in the SGD constructor will contain the learnable parameters of the two
#nn.Linear modules whoch are members of the model.
criterion=torch.nn.MSELoss(reduction='mean') #라이브러리
optimizer=torch.optim.SGD(model.parameters(),lr=0.01) #알고리즘 compute data same times-앞 영상방식 zip들어간 방식보다 효율적 

###step 3
#Training loop
for epoch in range(500):
  #forward poss: compute predicted y by passing x to the model
  y_pred = model(x_data) #s_data: x_data=matrix

  #Compute and print loss
  loss=criterion(y_pred, y_data) #MSE계산
  print(epoch, loss.item()) 

  #Zero gradients, perform a backward pass, and update the weights
  optimizer.zero_grad() #initialize all the gradients
  loss.backward()
  optimizer.step() #update variable <</////////how??

  #After Training
  hour_var=Variable (torch.Tensor([[4.0]]))
  print("predict (after training)", 4, model.forward(hour_var).data[0][0])
# Out:
# 0 13.282797813415527
# predict (after training) 4 tensor(1.8868)
# 1 10.514082908630371
# predict (after training) 4 tensor(2.5067)
# 2 8.325490951538086
# predict (after training) 4 tensor(3.0579)
# 3 6.595457077026367
# predict (after training) 4 tensor(3.5481)
# 4 5.22788667678833
# predict (after training) 4 tensor(3.9841)
# 5 4.146825313568115
# predict (after training) 4 tensor(4.3719)
# 6 3.2922351360321045
# predict (after training) 4 tensor(4.7168)
# 7 2.616658926010132
# predict (after training) 4 tensor(5.0236)
# 8 2.082582712173462
# predict (after training) 4 tensor(5.2965)
# 9 1.6603552103042603
# predict (after training) 4 tensor(5.5392)
# 10 1.3265395164489746
# predict (after training) 4 tensor(5.7552)
# 11 1.0626076459884644
# predict (after training) 4 tensor(5.9473)
# 12 0.8539164662361145
# predict (after training) 4 tensor(6.1183)
# 13 0.6888898015022278
# predict (after training) 4 tensor(6.2704)
# 14 0.5583785176277161
# predict (after training) 4 tensor(6.4058)
# 15 0.45514973998069763
# predict (after training) 4 tensor(6.5263)
# 16 0.37348678708076477
# predict (after training) 4 tensor(6.6336)
# 17 0.3088706433773041
# predict (after training) 4 tensor(6.7291)
# 18 0.25772973895072937
# predict (after training) 4 tensor(6.8142)
# 19 0.21724005043506622
# predict (after training) 4 tensor(6.8899)
# 20 0.1851702779531479
# predict (after training) 4 tensor(6.9574)
# 21 0.15975630283355713
# predict (after training) 4 tensor(7.0175)
# 22 0.13960367441177368
# predict (after training) 4 tensor(7.0711)
# 23 0.12360981851816177
# predict (after training) 4 tensor(7.1189)
# 24 0.11090412735939026
# predict (after training) 4 tensor(7.1615)
# 25 0.10079754143953323
# predict (after training) 4 tensor(7.1995)
# 26 0.09274560213088989
# predict (after training) 4 tensor(7.2335)
# 27 0.08631834387779236
# predict (after training) 4 tensor(7.2638)
# 28 0.08117552846670151
# predict (after training) 4 tensor(7.2909)
# 29 0.0770479068160057
# predict (after training) 4 tensor(7.3151)
# 30 0.07372377067804337
# predict (after training) 4 tensor(7.3367)
# 31 0.07103437185287476
# predict (after training) 4 tensor(7.3561)
# 32 0.06884744018316269
# predict (after training) 4 tensor(7.3734)
# 33 0.0670577883720398
# predict (after training) 4 tensor(7.3890)
# 34 0.06558244675397873
# predict (after training) 4 tensor(7.4030)
# 35 0.06435587257146835
# predict (after training) 4 tensor(7.4155)
# 36 0.06332627683877945
# predict (after training) 4 tensor(7.4268)
# 37 0.06245258450508118
# predict (after training) 4 tensor(7.4370)
# 38 0.06170239672064781
# predict (after training) 4 tensor(7.4461)
# 39 0.0610501728951931
# predict (after training) 4 tensor(7.4544)
# 40 0.06047578155994415
# predict (after training) 4 tensor(7.4619)
# 41 0.059962984174489975
# predict (after training) 4 tensor(7.4686)
# 42 0.05949930474162102
# predict (after training) 4 tensor(7.4748)
# 43 0.059074610471725464
# predict (after training) 4 tensor(7.4804)
# 44 0.058681175112724304
# predict (after training) 4 tensor(7.4855)
# 45 0.05831250548362732
# predict (after training) 4 tensor(7.4902)
# 46 0.05796391889452934
# predict (after training) 4 tensor(7.4944)
# 47 0.05763133242726326
# predict (after training) 4 tensor(7.4984)
# 48 0.05731167271733284
# predict (after training) 4 tensor(7.5020)
# 49 0.05700259283185005
# predict (after training) 4 tensor(7.5053)
# 50 0.056702058762311935
# predict (after training) 4 tensor(7.5084)
# 51 0.05640856921672821
# predict (after training) 4 tensor(7.5113)
# 52 0.05612099543213844
# predict (after training) 4 tensor(7.5140)
# 53 0.055838245898485184
# predict (after training) 4 tensor(7.5165)
# 54 0.055559705942869186
# predict (after training) 4 tensor(7.5188)
# 55 0.055284615606069565
# predict (after training) 4 tensor(7.5210)
# 56 0.05501260235905647
# predict (after training) 4 tensor(7.5231)
# 57 0.054743289947509766
# predict (after training) 4 tensor(7.5251)
# 58 0.054476361721754074
# predict (after training) 4 tensor(7.5270)
# 59 0.05421146750450134
# predict (after training) 4 tensor(7.5288)
# 60 0.053948622196912766
# predict (after training) 4 tensor(7.5305)
# 61 0.05368755757808685
# predict (after training) 4 tensor(7.5322)
# 62 0.053428128361701965
# predict (after training) 4 tensor(7.5338)
# 63 0.05317027494311333
# predict (after training) 4 tensor(7.5353)
# 64 0.052914004772901535
# predict (after training) 4 tensor(7.5368)
# 65 0.05265910550951958
# predict (after training) 4 tensor(7.5382)
# 66 0.05240555480122566
# predict (after training) 4 tensor(7.5396)
# 67 0.05215339735150337
# predict (after training) 4 tensor(7.5410)
# 68 0.05190255865454674
# predict (after training) 4 tensor(7.5423)
# 69 0.051653068512678146
# predict (after training) 4 tensor(7.5436)
# 70 0.05140472576022148
# predict (after training) 4 tensor(7.5449)
# 71 0.05115771293640137
# predict (after training) 4 tensor(7.5462)
# 72 0.05091192200779915
# predict (after training) 4 tensor(7.5474)
# 73 0.05066727474331856
# predict (after training) 4 tensor(7.5486)
# 74 0.050423961132764816
# predict (after training) 4 tensor(7.5498)
# 75 0.05018170177936554
# predict (after training) 4 tensor(7.5510)
# 76 0.04994065687060356
# predict (after training) 4 tensor(7.5522)
# 77 0.049700748175382614
# predict (after training) 4 tensor(7.5533)
# 78 0.04946211352944374
# predict (after training) 4 tensor(7.5545)
# 79 0.04922446981072426
# predict (after training) 4 tensor(7.5556)
# 80 0.04898815229535103
# predict (after training) 4 tensor(7.5567)
# 81 0.04875290393829346
# predict (after training) 4 tensor(7.5578)
# 82 0.04851866886019707
# predict (after training) 4 tensor(7.5589)
# 83 0.04828574135899544
# predict (after training) 4 tensor(7.5600)
# 84 0.048053812235593796
# predict (after training) 4 tensor(7.5611)
# 85 0.04782310500741005
# predict (after training) 4 tensor(7.5622)
# 86 0.04759335517883301
# predict (after training) 4 tensor(7.5633)
# 87 0.04736484959721565
# predict (after training) 4 tensor(7.5644)
# 88 0.04713737964630127
# predict (after training) 4 tensor(7.5654)
# 89 0.04691101983189583
# predict (after training) 4 tensor(7.5665)
# 90 0.046685840934515
# predict (after training) 4 tensor(7.5676)
# 91 0.0464615672826767
# predict (after training) 4 tensor(7.5686)
# 92 0.046238481998443604
# predict (after training) 4 tensor(7.5697)
# 93 0.04601643607020378
# predict (after training) 4 tensor(7.5707)
# 94 0.04579547047615051
# predict (after training) 4 tensor(7.5718)
# 95 0.04557553306221962
# predict (after training) 4 tensor(7.5728)
# 96 0.045356687158346176
# predict (after training) 4 tensor(7.5738)
# 97 0.045138880610466
# predict (after training) 4 tensor(7.5749)
# 98 0.04492212459445
# predict (after training) 4 tensor(7.5759)
# 99 0.04470639303326607
# predict (after training) 4 tensor(7.5769)
# 100 0.04449166730046272
# predict (after training) 4 tensor(7.5779)
# 101 0.04427800700068474
# predict (after training) 4 tensor(7.5790)
# 102 0.0440654456615448
# predict (after training) 4 tensor(7.5800)
# 103 0.04385380446910858
# predict (after training) 4 tensor(7.5810)
# 104 0.04364323243498802
# predict (after training) 4 tensor(7.5820)
# 105 0.04343365505337715
# predict (after training) 4 tensor(7.5830)
# 106 0.04322503134608269
# predict (after training) 4 tensor(7.5840)
# 107 0.04301747679710388
# predict (after training) 4 tensor(7.5850)
# 108 0.04281088709831238
# predict (after training) 4 tensor(7.5860)
# 109 0.04260529950261116
# predict (after training) 4 tensor(7.5870)
# 110 0.042400676757097244
# predict (after training) 4 tensor(7.5880)
# 111 0.042197126895189285
# predict (after training) 4 tensor(7.5890)
# 112 0.04199446365237236
# predict (after training) 4 tensor(7.5900)
# 113 0.0417928546667099
# predict (after training) 4 tensor(7.5910)
# 114 0.04159212484955788
# predict (after training) 4 tensor(7.5920)
# 115 0.04139244556427002
# predict (after training) 4 tensor(7.5929)
# 116 0.04119361191987991
# predict (after training) 4 tensor(7.5939)
# 117 0.040995851159095764
# predict (after training) 4 tensor(7.5949)
# 118 0.04079897329211235
# predict (after training) 4 tensor(7.5959)
# 119 0.04060307890176773
# predict (after training) 4 tensor(7.5968)
# 120 0.040408048778772354
# predict (after training) 4 tensor(7.5978)
# 121 0.040213990956544876
# predict (after training) 4 tensor(7.5988)
# 122 0.04002091661095619
# predict (after training) 4 tensor(7.5998)
# 123 0.03982868418097496
# predict (after training) 4 tensor(7.6007)
# 124 0.03963747248053551
# predict (after training) 4 tensor(7.6017)
# 125 0.03944706916809082
# predict (after training) 4 tensor(7.6026)
# 126 0.03925768658518791
# predict (after training) 4 tensor(7.6036)
# 127 0.03906913101673126
# predict (after training) 4 tensor(7.6045)
# 128 0.038881536573171616
# predict (after training) 4 tensor(7.6055)
# 129 0.03869478777050972
# predict (after training) 4 tensor(7.6064)
# 130 0.03850897029042244
# predict (after training) 4 tensor(7.6074)
# 131 0.03832405060529709
# predict (after training) 4 tensor(7.6083)
# 132 0.03814011439681053
# predict (after training) 4 tensor(7.6093)
# 133 0.03795691952109337
# predict (after training) 4 tensor(7.6102)
# 134 0.03777464106678963
# predict (after training) 4 tensor(7.6111)
# 135 0.03759324550628662
# predict (after training) 4 tensor(7.6121)
# 136 0.037412721663713455
# predict (after training) 4 tensor(7.6130)
# 137 0.037233076989650726
# predict (after training) 4 tensor(7.6139)
# 138 0.03705429658293724
# predict (after training) 4 tensor(7.6149)
# 139 0.03687632456421852
# predict (after training) 4 tensor(7.6158)
# 140 0.036699265241622925
# predict (after training) 4 tensor(7.6167)
# 141 0.036523014307022095
# predict (after training) 4 tensor(7.6176)
# 142 0.03634761646389961
# predict (after training) 4 tensor(7.6186)
# 143 0.0361730232834816
# predict (after training) 4 tensor(7.6195)
# 144 0.03599937632679939
# predict (after training) 4 tensor(7.6204)
# 145 0.03582646697759628
# predict (after training) 4 tensor(7.6213)
# 146 0.03565450385212898
# predict (after training) 4 tensor(7.6222)
# 147 0.03548325225710869
# predict (after training) 4 tensor(7.6231)
# 148 0.03531280905008316
# predict (after training) 4 tensor(7.6240)
# 149 0.03514322638511658
# predict (after training) 4 tensor(7.6249)
# 150 0.03497450798749924
# predict (after training) 4 tensor(7.6258)
# 151 0.034806571900844574
# predict (after training) 4 tensor(7.6267)
# 152 0.034639451652765274
# predict (after training) 4 tensor(7.6276)
# 153 0.03447310999035835
# predict (after training) 4 tensor(7.6285)
# 154 0.03430749848484993
# predict (after training) 4 tensor(7.6294)
# 155 0.03414279595017433
# predict (after training) 4 tensor(7.6303)
# 156 0.03397885337471962
# predict (after training) 4 tensor(7.6312)
# 157 0.03381562605500221
# predict (after training) 4 tensor(7.6321)
# 158 0.033653270453214645
# predict (after training) 4 tensor(7.6330)
# 159 0.03349166736006737
# predict (after training) 4 tensor(7.6339)
# 160 0.033330854028463364
# predict (after training) 4 tensor(7.6347)
# 161 0.033170800656080246
# predict (after training) 4 tensor(7.6356)
# 162 0.03301149606704712
# predict (after training) 4 tensor(7.6365)
# 163 0.03285297751426697
# predict (after training) 4 tensor(7.6374)
# 164 0.032695215195417404
# predict (after training) 4 tensor(7.6382)
# 165 0.032538216561079025
# predict (after training) 4 tensor(7.6391)
# 166 0.03238194063305855
# predict (after training) 4 tensor(7.6400)
# 167 0.032226432114839554
# predict (after training) 4 tensor(7.6408)
# 168 0.03207170218229294
# predict (after training) 4 tensor(7.6417)
# 169 0.03191770240664482
# predict (after training) 4 tensor(7.6426)
# 170 0.0317644327878952
# predict (after training) 4 tensor(7.6434)
# 171 0.031611885875463486
# predict (after training) 4 tensor(7.6443)
# 172 0.03146006539463997
# predict (after training) 4 tensor(7.6451)
# 173 0.03130900487303734
# predict (after training) 4 tensor(7.6460)
# 174 0.031158624216914177
# predict (after training) 4 tensor(7.6468)
# 175 0.03100900910794735
# predict (after training) 4 tensor(7.6477)
# 176 0.030860139057040215
# predict (after training) 4 tensor(7.6485)
# 177 0.030711935833096504
# predict (after training) 4 tensor(7.6494)
# 178 0.030564449727535248
# predict (after training) 4 tensor(7.6502)
# 179 0.030417660251259804
# predict (after training) 4 tensor(7.6511)
# 180 0.03027156926691532
# predict (after training) 4 tensor(7.6519)
# 181 0.030126238241791725
# predict (after training) 4 tensor(7.6527)
# 182 0.029981588944792747
# predict (after training) 4 tensor(7.6536)
# 183 0.029837599024176598
# predict (after training) 4 tensor(7.6544)
# 184 0.02969430945813656
# predict (after training) 4 tensor(7.6552)
# 185 0.029551686719059944
# predict (after training) 4 tensor(7.6561)
# 186 0.029409809038043022
# predict (after training) 4 tensor(7.6569)
# 187 0.029268577694892883
# predict (after training) 4 tensor(7.6577)
# 188 0.029128016903996468
# predict (after training) 4 tensor(7.6585)
# 189 0.028988145291805267
# predict (after training) 4 tensor(7.6594)
# 190 0.028848951682448387
# predict (after training) 4 tensor(7.6602)
# 191 0.02871043048799038
# predict (after training) 4 tensor(7.6610)
# 192 0.028572535142302513
# predict (after training) 4 tensor(7.6618)
# 193 0.02843535877764225
# predict (after training) 4 tensor(7.6626)
# 194 0.02829880826175213
# predict (after training) 4 tensor(7.6634)
# 195 0.028162918984889984
# predict (after training) 4 tensor(7.6642)
# 196 0.028027646243572235
# predict (after training) 4 tensor(7.6651)
# 197 0.027893031015992165
# predict (after training) 4 tensor(7.6659)
# 198 0.027759088203310966
# predict (after training) 4 tensor(7.6667)
# 199 0.027625828981399536
# predict (after training) 4 tensor(7.6675)
# 200 0.02749316394329071
# predict (after training) 4 tensor(7.6683)
# 201 0.027361124753952026
# predict (after training) 4 tensor(7.6691)
# 202 0.027229735627770424
# predict (after training) 4 tensor(7.6699)
# 203 0.027098963037133217
# predict (after training) 4 tensor(7.6706)
# 204 0.026968836784362793
# predict (after training) 4 tensor(7.6714)
# 205 0.026839302852749825
# predict (after training) 4 tensor(7.6722)
# 206 0.026710495352745056
# predict (after training) 4 tensor(7.6730)
# 207 0.02658216655254364
# predict (after training) 4 tensor(7.6738)
# 208 0.026454506441950798
# predict (after training) 4 tensor(7.6746)
# 209 0.026327526196837425
# predict (after training) 4 tensor(7.6754)
# 210 0.02620108611881733
# predict (after training) 4 tensor(7.6762)
# 211 0.02607523463666439
# predict (after training) 4 tensor(7.6769)
# 212 0.025950061157345772
# predict (after training) 4 tensor(7.6777)
# 213 0.025825418531894684
# predict (after training) 4 tensor(7.6785)
# 214 0.025701403617858887
# predict (after training) 4 tensor(7.6793)
# 215 0.025578012689948082
# predict (after training) 4 tensor(7.6800)
# 216 0.025455189868807793
# predict (after training) 4 tensor(7.6808)
# 217 0.02533290721476078
# predict (after training) 4 tensor(7.6816)
# 218 0.025211267173290253
# predict (after training) 4 tensor(7.6823)
# 219 0.025090167298913002
# predict (after training) 4 tensor(7.6831)
# 220 0.02496972680091858
# predict (after training) 4 tensor(7.6839)
# 221 0.024849796667695045
# predict (after training) 4 tensor(7.6846)
# 222 0.02473047934472561
# predict (after training) 4 tensor(7.6854)
# 223 0.024611713364720345
# predict (after training) 4 tensor(7.6861)
# 224 0.024493515491485596
# predict (after training) 4 tensor(7.6869)
# 225 0.024375950917601585
# predict (after training) 4 tensor(7.6876)
# 226 0.02425887994468212
# predict (after training) 4 tensor(7.6884)
# 227 0.024142391979694366
# predict (after training) 4 tensor(7.6891)
# 228 0.024026447907090187
# predict (after training) 4 tensor(7.6899)
# 229 0.023911060765385628
# predict (after training) 4 tensor(7.6906)
# 230 0.023796191439032555
# predict (after training) 4 tensor(7.6914)
# 231 0.02368197776377201
# predict (after training) 4 tensor(7.6921)
# 232 0.023568272590637207
# predict (after training) 4 tensor(7.6929)
# 233 0.02345506101846695
# predict (after training) 4 tensor(7.6936)
# 234 0.023342400789260864
# predict (after training) 4 tensor(7.6943)
# 235 0.02323036454617977
# predict (after training) 4 tensor(7.6951)
# 236 0.02311880886554718
# predict (after training) 4 tensor(7.6958)
# 237 0.02300778590142727
# predict (after training) 4 tensor(7.6965)
# 238 0.022897273302078247
# predict (after training) 4 tensor(7.6973)
# 239 0.022787325084209442
# predict (after training) 4 tensor(7.6980)
# 240 0.022677898406982422
# predict (after training) 4 tensor(7.6987)
# 241 0.022569043561816216
# predict (after training) 4 tensor(7.6994)
# 242 0.02246060036122799
# predict (after training) 4 tensor(7.7002)
# 243 0.022352755069732666
# predict (after training) 4 tensor(7.7009)
# 244 0.022245394065976143
# predict (after training) 4 tensor(7.7016)
# 245 0.022138603031635284
# predict (after training) 4 tensor(7.7023)
# 246 0.02203231491148472
# predict (after training) 4 tensor(7.7030)
# 247 0.021926501765847206
# predict (after training) 4 tensor(7.7037)
# 248 0.02182120829820633
# predict (after training) 4 tensor(7.7045)
# 249 0.02171643078327179
# predict (after training) 4 tensor(7.7052)
# 250 0.021612083539366722
# predict (after training) 4 tensor(7.7059)
# 251 0.021508323028683662
# predict (after training) 4 tensor(7.7066)
# 252 0.021405061706900597
# predict (after training) 4 tensor(7.7073)
# 253 0.021302273496985435
# predict (after training) 4 tensor(7.7080)
# 254 0.021199947223067284
# predict (after training) 4 tensor(7.7087)
# 255 0.02109816111624241
# predict (after training) 4 tensor(7.7094)
# 256 0.020996883511543274
# predict (after training) 4 tensor(7.7101)
# 257 0.020896023139357567
# predict (after training) 4 tensor(7.7108)
# 258 0.020795660093426704
# predict (after training) 4 tensor(7.7115)
# 259 0.020695865154266357
# predict (after training) 4 tensor(7.7122)
# 260 0.02059645764529705
# predict (after training) 4 tensor(7.7129)
# 261 0.020497528836131096
# predict (after training) 4 tensor(7.7136)
# 262 0.020399093627929688
# predict (after training) 4 tensor(7.7142)
# 263 0.020301105454564095
# predict (after training) 4 tensor(7.7149)
# 264 0.02020368166267872
# predict (after training) 4 tensor(7.7156)
# 265 0.020106641575694084
# predict (after training) 4 tensor(7.7163)
# 266 0.020010070875287056
# predict (after training) 4 tensor(7.7170)
# 267 0.01991402730345726
# predict (after training) 4 tensor(7.7177)
# 268 0.019818346947431564
# predict (after training) 4 tensor(7.7183)
# 269 0.019723184406757355
# predict (after training) 4 tensor(7.7190)
# 270 0.019628489390015602
# predict (after training) 4 tensor(7.7197)
# 271 0.019534235820174217
# predict (after training) 4 tensor(7.7204)
# 272 0.019440429285168648
# predict (after training) 4 tensor(7.7210)
# 273 0.019347084686160088
# predict (after training) 4 tensor(7.7217)
# 274 0.01925414241850376
# predict (after training) 4 tensor(7.7224)
# 275 0.019161732867360115
# predict (after training) 4 tensor(7.7231)
# 276 0.019069673493504524
# predict (after training) 4 tensor(7.7237)
# 277 0.018978126347064972
# predict (after training) 4 tensor(7.7244)
# 278 0.01888696663081646
# predict (after training) 4 tensor(7.7250)
# 279 0.018796265125274658
# predict (after training) 4 tensor(7.7257)
# 280 0.018706029281020164
# predict (after training) 4 tensor(7.7264)
# 281 0.018616212531924248
# predict (after training) 4 tensor(7.7270)
# 282 0.018526820465922356
# predict (after training) 4 tensor(7.7277)
# 283 0.018437840044498444
# predict (after training) 4 tensor(7.7283)
# 284 0.018349315971136093
# predict (after training) 4 tensor(7.7290)
# 285 0.018261170014739037
# predict (after training) 4 tensor(7.7296)
# 286 0.018173476681113243
# predict (after training) 4 tensor(7.7303)
# 287 0.018086228519678116
# predict (after training) 4 tensor(7.7309)
# 288 0.01799936033785343
# predict (after training) 4 tensor(7.7316)
# 289 0.01791290007531643
# predict (after training) 4 tensor(7.7322)
# 290 0.017826883122324944
# predict (after training) 4 tensor(7.7329)
# 291 0.017741283401846886
# predict (after training) 4 tensor(7.7335)
# 292 0.017656106501817703
# predict (after training) 4 tensor(7.7342)
# 293 0.017571305856108665
# predict (after training) 4 tensor(7.7348)
# 294 0.017486922442913055
# predict (after training) 4 tensor(7.7354)
# 295 0.01740295998752117
# predict (after training) 4 tensor(7.7361)
# 296 0.01731940358877182
# predict (after training) 4 tensor(7.7367)
# 297 0.017236201092600822
# predict (after training) 4 tensor(7.7373)
# 298 0.017153440043330193
# predict (after training) 4 tensor(7.7380)
# 299 0.017071077600121498
# predict (after training) 4 tensor(7.7386)
# 300 0.016989106312394142
# predict (after training) 4 tensor(7.7392)
# 301 0.01690748706459999
# predict (after training) 4 tensor(7.7399)
# 302 0.01682629995048046
# predict (after training) 4 tensor(7.7405)
# 303 0.016745509579777718
# predict (after training) 4 tensor(7.7411)
# 304 0.016665132716298103
# predict (after training) 4 tensor(7.7417)
# 305 0.016585106030106544
# predict (after training) 4 tensor(7.7423)
# 306 0.016505440697073936
# predict (after training) 4 tensor(7.7430)
# 307 0.01642618328332901
# predict (after training) 4 tensor(7.7436)
# 308 0.016347279772162437
# predict (after training) 4 tensor(7.7442)
# 309 0.01626880094408989
# predict (after training) 4 tensor(7.7448)
# 310 0.016190698370337486
# predict (after training) 4 tensor(7.7454)
# 311 0.016112903133034706
# predict (after training) 4 tensor(7.7460)
# 312 0.016035553067922592
# predict (after training) 4 tensor(7.7466)
# 313 0.015958577394485474
# predict (after training) 4 tensor(7.7473)
# 314 0.015881896018981934
# predict (after training) 4 tensor(7.7479)
# 315 0.01580563187599182
# predict (after training) 4 tensor(7.7485)
# 316 0.0157297533005476
# predict (after training) 4 tensor(7.7491)
# 317 0.01565420813858509
# predict (after training) 4 tensor(7.7497)
# 318 0.015579053200781345
# predict (after training) 4 tensor(7.7503)
# 319 0.015504258684813976
# predict (after training) 4 tensor(7.7509)
# 320 0.015429777093231678
# predict (after training) 4 tensor(7.7515)
# 321 0.015355702489614487
# predict (after training) 4 tensor(7.7521)
# 322 0.015281935222446918
# predict (after training) 4 tensor(7.7527)
# 323 0.015208552591502666
# predict (after training) 4 tensor(7.7533)
# 324 0.015135511755943298
# predict (after training) 4 tensor(7.7539)
# 325 0.01506283413618803
# predict (after training) 4 tensor(7.7545)
# 326 0.014990502037107944
# predict (after training) 4 tensor(7.7550)
# 327 0.01491854339838028
# predict (after training) 4 tensor(7.7556)
# 328 0.014846893958747387
# predict (after training) 4 tensor(7.7562)
# 329 0.014775586314499378
# predict (after training) 4 tensor(7.7568)
# 330 0.014704613946378231
# predict (after training) 4 tensor(7.7574)
# 331 0.014634005725383759
# predict (after training) 4 tensor(7.7580)
# 332 0.014563786797225475
# predict (after training) 4 tensor(7.7586)
# 333 0.014493814669549465
# predict (after training) 4 tensor(7.7591)
# 334 0.014424189925193787
# predict (after training) 4 tensor(7.7597)
# 335 0.014354920946061611
# predict (after training) 4 tensor(7.7603)
# 336 0.014286021701991558
# predict (after training) 4 tensor(7.7609)
# 337 0.014217417687177658
# predict (after training) 4 tensor(7.7614)
# 338 0.01414914708584547
# predict (after training) 4 tensor(7.7620)
# 339 0.014081167988479137
# predict (after training) 4 tensor(7.7626)
# 340 0.014013553969562054
# predict (after training) 4 tensor(7.7632)
# 341 0.013946250081062317
# predict (after training) 4 tensor(7.7637)
# 342 0.013879329897463322
# predict (after training) 4 tensor(7.7643)
# 343 0.013812673278152943
# predict (after training) 4 tensor(7.7649)
# 344 0.013746327720582485
# predict (after training) 4 tensor(7.7654)
# 345 0.013680297881364822
# predict (after training) 4 tensor(7.7660)
# 346 0.013614614494144917
# predict (after training) 4 tensor(7.7666)
# 347 0.013549250550568104
# predict (after training) 4 tensor(7.7671)
# 348 0.013484175316989422
# predict (after training) 4 tensor(7.7677)
# 349 0.013419448398053646
# predict (after training) 4 tensor(7.7682)
# 350 0.013354976661503315
# predict (after training) 4 tensor(7.7688)
# 351 0.01329087745398283
# predict (after training) 4 tensor(7.7693)
# 352 0.013227037154138088
# predict (after training) 4 tensor(7.7699)
# 353 0.013163493014872074
# predict (after training) 4 tensor(7.7705)
# 354 0.01310028601437807
# predict (after training) 4 tensor(7.7710)
# 355 0.013037395663559437
# predict (after training) 4 tensor(7.7716)
# 356 0.012974798679351807
# predict (after training) 4 tensor(7.7721)
# 357 0.012912497855722904
# predict (after training) 4 tensor(7.7727)
# 358 0.012850455939769745
# predict (after training) 4 tensor(7.7732)
# 359 0.012788757681846619
# predict (after training) 4 tensor(7.7737)
# 360 0.012727337889373302
# predict (after training) 4 tensor(7.7743)
# 361 0.012666218914091587
# predict (after training) 4 tensor(7.7748)
# 362 0.012605424970388412
# predict (after training) 4 tensor(7.7754)
# 363 0.012544882483780384
# predict (after training) 4 tensor(7.7759)
# 364 0.012484632432460785
# predict (after training) 4 tensor(7.7765)
# 365 0.012424691580235958
# predict (after training) 4 tensor(7.7770)
# 366 0.012365010567009449
# predict (after training) 4 tensor(7.7775)
# 367 0.012305636890232563
# predict (after training) 4 tensor(7.7781)
# 368 0.012246526777744293
# predict (after training) 4 tensor(7.7786)
# 369 0.01218770444393158
# predict (after training) 4 tensor(7.7791)
# 370 0.012129207141697407
# predict (after training) 4 tensor(7.7797)
# 371 0.012070960365235806
# predict (after training) 4 tensor(7.7802)
# 372 0.012013011611998081
# predict (after training) 4 tensor(7.7807)
# 373 0.011955305933952332
# predict (after training) 4 tensor(7.7812)
# 374 0.011897921562194824
# predict (after training) 4 tensor(7.7818)
# 375 0.011840770952403545
# predict (after training) 4 tensor(7.7823)
# 376 0.011783895082771778
# predict (after training) 4 tensor(7.7828)
# 377 0.011727292090654373
# predict (after training) 4 tensor(7.7833)
# 378 0.011670995503664017
# predict (after training) 4 tensor(7.7839)
# 379 0.011614936403930187
# predict (after training) 4 tensor(7.7844)
# 380 0.011559194885194302
# predict (after training) 4 tensor(7.7849)
# 381 0.011503648944199085
# predict (after training) 4 tensor(7.7854)
# 382 0.011448430828750134
# predict (after training) 4 tensor(7.7859)
# 383 0.011393475346267223
# predict (after training) 4 tensor(7.7864)
# 384 0.011338754557073116
# predict (after training) 4 tensor(7.7870)
# 385 0.011284301988780499
# predict (after training) 4 tensor(7.7875)
# 386 0.011230111122131348
# predict (after training) 4 tensor(7.7880)
# 387 0.01117617916315794
# predict (after training) 4 tensor(7.7885)
# 388 0.01112251728773117
# predict (after training) 4 tensor(7.7890)
# 389 0.011069081723690033
# predict (after training) 4 tensor(7.7895)
# 390 0.011015944182872772
# predict (after training) 4 tensor(7.7900)
# 391 0.010963059961795807
# predict (after training) 4 tensor(7.7905)
# 392 0.010910400189459324
# predict (after training) 4 tensor(7.7910)
# 393 0.010858009569346905
# predict (after training) 4 tensor(7.7915)
# 394 0.010805864818394184
# predict (after training) 4 tensor(7.7920)
# 395 0.01075395941734314
# predict (after training) 4 tensor(7.7925)
# 396 0.010702340863645077
# predict (after training) 4 tensor(7.7930)
# 397 0.01065095979720354
# predict (after training) 4 tensor(7.7935)
# 398 0.010599787347018719
# predict (after training) 4 tensor(7.7940)
# 399 0.010548890568315983
# predict (after training) 4 tensor(7.7945)
# 400 0.01049825083464384
# predict (after training) 4 tensor(7.7950)
# 401 0.010447826236486435
# predict (after training) 4 tensor(7.7955)
# 402 0.010397660546004772
# predict (after training) 4 tensor(7.7960)
# 403 0.010347704403102398
# predict (after training) 4 tensor(7.7965)
# 404 0.010298027656972408
# predict (after training) 4 tensor(7.7970)
# 405 0.010248576290905476
# predict (after training) 4 tensor(7.7975)
# 406 0.010199367068707943
# predict (after training) 4 tensor(7.7979)
# 407 0.01015040185302496
# predict (after training) 4 tensor(7.7984)
# 408 0.01010165736079216
# predict (after training) 4 tensor(7.7989)
# 409 0.010053101927042007
# predict (after training) 4 tensor(7.7994)
# 410 0.010004875250160694
# predict (after training) 4 tensor(7.7999)
# 411 0.009956804104149342
# predict (after training) 4 tensor(7.8004)
# 412 0.009909025393426418
# predict (after training) 4 tensor(7.8008)
# 413 0.009861412458121777
# predict (after training) 4 tensor(7.8013)
# 414 0.009814047254621983
# predict (after training) 4 tensor(7.8018)
# 415 0.009766931645572186
# predict (after training) 4 tensor(7.8023)
# 416 0.0097200321033597
# predict (after training) 4 tensor(7.8027)
# 417 0.00967334397137165
# predict (after training) 4 tensor(7.8032)
# 418 0.009626894257962704
# predict (after training) 4 tensor(7.8037)
# 419 0.009580650366842747
# predict (after training) 4 tensor(7.8042)
# 420 0.009534689597785473
# predict (after training) 4 tensor(7.8046)
# 421 0.009488865733146667
# predict (after training) 4 tensor(7.8051)
# 422 0.00944332405924797
# predict (after training) 4 tensor(7.8056)
# 423 0.009397941641509533
# predict (after training) 4 tensor(7.8060)
# 424 0.009352830238640308
# predict (after training) 4 tensor(7.8065)
# 425 0.009307910688221455
# predict (after training) 4 tensor(7.8070)
# 426 0.009263207204639912
# predict (after training) 4 tensor(7.8074)
# 427 0.009218740276992321
# predict (after training) 4 tensor(7.8079)
# 428 0.009174480102956295
# predict (after training) 4 tensor(7.8084)
# 429 0.00913041178137064
# predict (after training) 4 tensor(7.8088)
# 430 0.009086581878364086
# predict (after training) 4 tensor(7.8093)
# 431 0.009042966179549694
# predict (after training) 4 tensor(7.8097)
# 432 0.008999506942927837
# predict (after training) 4 tensor(7.8102)
# 433 0.008956294506788254
# predict (after training) 4 tensor(7.8107)
# 434 0.008913283236324787
# predict (after training) 4 tensor(7.8111)
# 435 0.008870468474924564
# predict (after training) 4 tensor(7.8116)
# 436 0.008827869780361652
# predict (after training) 4 tensor(7.8120)
# 437 0.008785496465861797
# predict (after training) 4 tensor(7.8125)
# 438 0.008743294514715672
# predict (after training) 4 tensor(7.8129)
# 439 0.008701340295374393
# predict (after training) 4 tensor(7.8134)
# 440 0.0086595444008708
# predict (after training) 4 tensor(7.8138)
# 441 0.008617955259978771
# predict (after training) 4 tensor(7.8143)
# 442 0.008576574735343456
# predict (after training) 4 tensor(7.8147)
# 443 0.008535363711416721
# predict (after training) 4 tensor(7.8152)
# 444 0.008494389243423939
# predict (after training) 4 tensor(7.8156)
# 445 0.008453588001430035
# predict (after training) 4 tensor(7.8160)
# 446 0.008413022384047508
# predict (after training) 4 tensor(7.8165)
# 447 0.00837261974811554
# predict (after training) 4 tensor(7.8169)
# 448 0.00833242479711771
# predict (after training) 4 tensor(7.8174)
# 449 0.008292398415505886
# predict (after training) 4 tensor(7.8178)
# 450 0.008252567611634731
# predict (after training) 4 tensor(7.8182)
# 451 0.008212941698729992
# predict (after training) 4 tensor(7.8187)
# 452 0.00817349273711443
# predict (after training) 4 tensor(7.8191)
# 453 0.008134257979691029
# predict (after training) 4 tensor(7.8196)
# 454 0.00809518899768591
# predict (after training) 4 tensor(7.8200)
# 455 0.008056326769292355
# predict (after training) 4 tensor(7.8204)
# 456 0.008017615415155888
# predict (after training) 4 tensor(7.8209)
# 457 0.007979143410921097
# predict (after training) 4 tensor(7.8213)
# 458 0.007940802723169327
# predict (after training) 4 tensor(7.8217)
# 459 0.007902664132416248
# predict (after training) 4 tensor(7.8221)
# 460 0.007864735089242458
# predict (after training) 4 tensor(7.8226)
# 461 0.007826960645616055
# predict (after training) 4 tensor(7.8230)
# 462 0.007789370138198137
# predict (after training) 4 tensor(7.8234)
# 463 0.007751970086246729
# predict (after training) 4 tensor(7.8238)
# 464 0.007714730221778154
# predict (after training) 4 tensor(7.8243)
# 465 0.007677696645259857
# predict (after training) 4 tensor(7.8247)
# 466 0.007640838157385588
# predict (after training) 4 tensor(7.8251)
# 467 0.007604151498526335
# predict (after training) 4 tensor(7.8255)
# 468 0.007567637134343386
# predict (after training) 4 tensor(7.8260)
# 469 0.007531290408223867
# predict (after training) 4 tensor(7.8264)
# 470 0.007495129015296698
# predict (after training) 4 tensor(7.8268)
# 471 0.007459144573658705
# predict (after training) 4 tensor(7.8272)
# 472 0.007423287723213434
# predict (after training) 4 tensor(7.8276)
# 473 0.0073876469396054745
# predict (after training) 4 tensor(7.8280)
# 474 0.007352171931415796
# predict (after training) 4 tensor(7.8284)
# 475 0.0073168775998055935
# predict (after training) 4 tensor(7.8289)
# 476 0.007281748112291098
# predict (after training) 4 tensor(7.8293)
# 477 0.007246766239404678
# predict (after training) 4 tensor(7.8297)
# 478 0.00721195712685585
# predict (after training) 4 tensor(7.8301)
# 479 0.007177313789725304
# predict (after training) 4 tensor(7.8305)
# 480 0.0071428678929805756
# predict (after training) 4 tensor(7.8309)
# 481 0.007108559366315603
# predict (after training) 4 tensor(7.8313)
# 482 0.007074428256601095
# predict (after training) 4 tensor(7.8317)
# 483 0.007040474563837051
# predict (after training) 4 tensor(7.8321)
# 484 0.007006670814007521
# predict (after training) 4 tensor(7.8325)
# 485 0.00697300722822547
# predict (after training) 4 tensor(7.8329)
# 486 0.006939514074474573
# predict (after training) 4 tensor(7.8333)
# 487 0.006906196940690279
# predict (after training) 4 tensor(7.8337)
# 488 0.006873026490211487
# predict (after training) 4 tensor(7.8341)
# 489 0.0068400464951992035
# predict (after training) 4 tensor(7.8345)
# 490 0.006807196419686079
# predict (after training) 4 tensor(7.8349)
# 491 0.006774493958801031
# predict (after training) 4 tensor(7.8353)
# 492 0.006741955876350403
# predict (after training) 4 tensor(7.8357)
# 493 0.0067095886915922165
# predict (after training) 4 tensor(7.8361)
# 494 0.006677369121462107
# predict (after training) 4 tensor(7.8365)
# 495 0.0066453032195568085
# predict (after training) 4 tensor(7.8369)
# 496 0.006613402161747217
# predict (after training) 4 tensor(7.8373)
# 497 0.006581638008356094
# predict (after training) 4 tensor(7.8377)
# 498 0.006550047546625137
# predict (after training) 4 tensor(7.8381)
# 499 0.006518579553812742
# predict (after training) 4 tensor(7.8385)
